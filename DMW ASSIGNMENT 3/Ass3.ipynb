# %% [markdown]
# construct the fp(frequent pattern) tree for given transaction dataset using suitable programming language for appropriate dataset for association mining and perform following operations,
# 1) find the max ferquent item set
# 2) how many transactions does it contains
# 3) simulate the frequent pattern
# 4) compare this algorithm with approire algorithm.
# NOTES:
# ->Support and confidence are the two elements of apriori algorithm.
# ->support of the item set is the number of transaction in which the item set appears.
# ->confidence : confidence is the measure of likelihood that an item set will be appear if another item set appears.
# ->

# %%
# Step 1: Load and Preprocess Dataset
import pandas as pd
from collections import defaultdict
from itertools import combinations

# %%
# Load dataset
def load_data(file_path):
    df = pd.read_csv(file_path)
    transactions = df.iloc[:, 1:].apply(lambda x: x.dropna().tolist(), axis=1).tolist()
    return transactions

file_path = r"groceries.csv"
transactions = load_data(file_path)
transactions
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['beef'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetable juice', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['sausage', 'rolls/buns', 'soda', 'chocolate'],
#  ['other vegetables'],
#  ['brown bread',
#   'soda',
#   'fruit/vegetable juice',
#   'canned beer',
#   'newspapers',
#   'shopping bags'],
#  ['yogurt', 'beverages', 'bottled water', 'specialty bar'],
#  ['hamburger meat',
#   'other vegetables',
#   'rolls/buns',
#   'spices',
#   'bottled water',
#   'hygiene articles',
#   'napkins'],
#  ['root vegetables', 'other vegetables', 'whole milk', 'beverages', 'sugar'],
#  ['pork',
#   'berries',
#   'other vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'artif. sweetener',
#   'soda',
#   'abrasive cleaner'],
#  ['beef', 'grapes', 'detergent'],
#  ['pastry', 'soda'],
#  ['fruit/vegetable juice'],
#  ['canned beer'],
#  ['root vegetables', 'other vegetables', 'whole milk', 'dessert'],
#  ['citrus fruit', 'zwieback', 'newspapers'],
#  ['sausage',
#   'rolls/buns',
#   'soda',
#   'canned beer',
#   'specialty bar',
#   'shopping bags'],
#  ['tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'yogurt',
#   'domestic eggs',
#   'brown bread',
#   'pastry',
#   'sugar',
#   'cereals',
#   'coffee',
#   'soda',
#   'waffles',
#   'candy'],
#  ['berries', 'yogurt'],
#  ['canned beer'],
#  ['butter milk',
#   'yogurt',
#   'cream cheese',
#   'spread cheese',
#   'rolls/buns',
#   'bottled water',
#   'soda',
#   'newspapers'],
#  ['coffee'],
#  ['pastry', 'bottled water'],
#  ['rolls/buns'],
#  ['misc. beverages'],
#  ['root vegetables',
#   'other vegetables',
#   'butter',
#   'curd',
#   'whipped/sour cream',
#   'UHT-milk',
#   'hard cheese',
#   'rolls/buns',
#   'bottled water',
#   'long life bakery product'],
#  ['sausage', 'rolls/buns', 'cat food', 'newspapers'],
#  ['canned beer'],
#  ['ham', 'grapes', 'other vegetables', 'whole milk'],
#  ['turkey',
#   'tropical fruit',
#   'other vegetables',
#   'curd',
#   'domestic eggs',
#   'brown bread',
#   'semi-finished bread',
#   'margarine',
#   'baking powder',
#   'fruit/vegetable juice'],
#  ['whole milk', 'yogurt', 'processed cheese', 'pickled vegetables', 'soda'],
#  ['whole milk', 'curd', 'yogurt', 'pastry'],
#  ['packaged fruit/vegetables', 'brown bread', 'canned beer'],
#  ['rolls/buns',
#   'oil',
#   'bottled water',
#   'chewing gum',
#   'chocolate marshmallow',
#   'hygiene articles',
#   'napkins'],
#  ['ham', 'beef', 'whipped/sour cream', 'ice cream', 'rolls/buns', 'cat food'],
#  ['rolls/buns', 'pastry', 'sugar'],
#  ['other vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'canned fish',
#   'salty snack',
#   'seasonal products',
#   'detergent'],
#  ['sausage', 'pastry'],
#  ['sausage', 'beef', 'whole milk'],
#  ['frankfurter', 'tropical fruit', 'rolls/buns', 'brown bread', 'sugar'],
#  ['rolls/buns', 'pastry', 'soda'],
#  ['whole milk'],
#  ['curd cheese', 'coffee'],
#  ['red/blush wine', 'newspapers'],
#  ['sausage', 'whole milk', 'curd'],
#  ['tropical fruit',
#   'pip fruit',
#   'berries',
#   'whole milk',
#   'frozen potato products',
#   'rolls/buns',
#   'pickled vegetables',
#   'chocolate'],
#  ['red/blush wine'],
#  ['whole milk',
#   'butter',
#   'margarine',
#   'specialty fat',
#   'specialty chocolate',
#   'candles',
#   'flower (seeds)'],
#  ['frankfurter',
#   'citrus fruit',
#   'whole milk',
#   'domestic eggs',
#   'oil',
#   'sparkling wine',
#   'specialty chocolate',
#   'newspapers'],
#  ['whole milk', 'meat spreads', 'soda'],
#  ['frozen potato products'],
#  ['other vegetables', 'whole milk', 'rolls/buns', 'sugar'],
#  ['citrus fruit', 'whole milk', 'curd', 'butter milk', 'pastry'],
#  ['flour', 'salt', 'bottled water', 'fruit/vegetable juice', 'bottled beer'],
#  ['sugar', 'bottled water', 'soda', 'bottled beer'],
#  ['frozen meals', 'coffee'],
#  ['chocolate'],
#  ['root vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'domestic eggs',
#   'rolls/buns',
#   'oil',
#   'margarine',
#   'canned vegetables',
#   'fruit/vegetable juice',
#   'bathroom cleaner'],
#  ['root vegetables', 'onions', 'hard cheese', 'frozen vegetables'],
#  ['herbs',
#   'condensed milk',
#   'frozen vegetables',
#   'salt',
#   'oil',
#   'white wine',
#   'candles'],
#  ['bottled water'],
#  ['sausage',
#   'root vegetables',
#   'onions',
#   'yogurt',
#   'rolls/buns',
#   'brandy',
#   'detergent'],
#  ['coffee', 'newspapers'],
#  ['pork', 'other vegetables', 'whipped/sour cream'],
#  ['berries', 'yogurt'],
#  ['soda'],
#  ['berries'],
#  ['fruit/vegetable juice', 'salty snack', 'candles'],
#  ['citrus fruit', 'butter milk', 'yogurt', 'cream cheese'],
#  ['pork',
#   'hamburger meat',
#   'citrus fruit',
#   'berries',
#   'onions',
#   'whipped/sour cream',
#   'rice',
#   'coffee',
#   'chocolate'],
#  ['detergent'],
#  ['grapes', 'photo/film'],
#  ['sausage',
#   'sliced cheese',
#   'rolls/buns',
#   'brown bread',
#   'fruit/vegetable juice',
#   'canned beer',
#   'red/blush wine',
#   'waffles',
#   'shopping bags'],
#  ['chicken',
#   'hamburger meat',
#   'citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'butter',
#   'pasta',
#   'oil',
#   'detergent'],
#  ['whole milk', 'yogurt', 'brown bread'],
#  ['citrus fruit', 'tropical fruit'],
#  ['soda', 'misc. beverages'],
#  ['sausage',
#   'pork',
#   'grapes',
#   'whole milk',
#   'rolls/buns',
#   'pastry',
#   'soda',
#   'specialty bar',
#   'bathroom cleaner'],
#  ['frankfurter', 'rolls/buns', 'bottled water'],
#  ['sausage',
#   'whole milk',
#   'yogurt',
#   'coffee',
#   'fruit/vegetable juice',
#   'bottled beer',
#   'softener',
#   'napkins',
#   'photo/film',
#   'shopping bags'],
#  ['soda'],
#  ['rolls/buns', 'fruit/vegetable juice'],
#  ['beef',
#   'citrus fruit',
#   'berries',
#   'root vegetables',
#   'brown bread',
#   'detergent'],
#  ['whole milk',
#   'whipped/sour cream',
#   'rolls/buns',
#   'soda',
#   'waffles',
#   'candy',
#   'cling film/bags'],
#  ['processed cheese'],
#  ['tropical fruit', 'pip fruit'],
#  ['frankfurter',
#   'sausage',
#   'root vegetables',
#   'other vegetables',
#   'rolls/buns',
#   'oil',
#   'pickled vegetables',
#   'bottled beer',
#   'chewing gum',
#   'dishes'],
#  ['packaged fruit/vegetables', 'bottled water'],
#  ['whole milk',
#   'dessert',
#   'frozen vegetables',
#   'rolls/buns',
#   'margarine',
#   'bottled water',
#   'red/blush wine',
#   'newspapers'],
#  ['berries', 'whipped/sour cream'],
#  ['citrus fruit', 'berries', 'UHT-milk', 'processed cheese'],
#  ['tropical fruit', 'whole milk', 'yogurt'],
#  ['hamburger meat',
#   'whole milk',
#   'frozen vegetables',
#   'rolls/buns',
#   'bottled beer',
#   'sparkling wine'],
#  ['hamburger meat',
#   'other vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'domestic eggs',
#   'soda',
#   'dishes'],
#  ['whole milk', 'cream cheese', 'soda'],
#  ['fish',
#   'other vegetables',
#   'pastry',
#   'margarine',
#   'coffee',
#   'long life bakery product',
#   'male cosmetics',
#   'shopping bags'],
#  ['frankfurter', 'sausage', 'long life bakery product', 'waffles'],
#  ['packaged fruit/vegetables',
#   'dessert',
#   'semi-finished bread',
#   'canned beer'],
#  ['pastry', 'soda'],
#  ['other vegetables', 'red/blush wine'],
#  ['misc. beverages'],
#  ['frankfurter',
#   'sausage',
#   'citrus fruit',
#   'tropical fruit',
#   'pip fruit',
#   'whole milk',
#   'hard cheese',
#   'cream cheese',
#   'domestic eggs',
#   'rice',
#   'sugar',
#   'canned fruit',
#   'misc. beverages',
#   'fruit/vegetable juice',
#   'hygiene articles'],
#  ['sparkling wine'],
#  ['specialty bar'],
#  ['sausage', 'butter milk', 'rolls/buns'],
#  ['curd cheese'],
#  ['frankfurter', 'dessert'],
#  ['whole milk', 'yogurt', 'beverages', 'brown bread', 'shopping bags'],
#  ['newspapers'],
#  ['berries', 'soda'],
#  ['curd', 'flour', 'liquor (appetizer)'],
#  ['tropical fruit', 'other vegetables', 'coffee'],
#  ['soda'],
#  ['rolls/buns', 'Instant food products'],
#  ['canned beer'],
#  ['canned beer'],
#  ['frankfurter', 'sausage', 'whole milk', 'rolls/buns', 'margarine'],
#  ['other vegetables', 'misc. beverages', 'canned beer'],
#  ['whole milk', 'frozen vegetables'],
#  ['whole milk'],
#  ['citrus fruit',
#   'butter',
#   'cream cheese',
#   'white bread',
#   'oil',
#   'margarine',
#   'newspapers'],
#  ['frankfurter', 'rolls/buns'],
#  ['frankfurter',
#   'ham',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'soft cheese',
#   'frozen vegetables',
#   'rolls/buns',
#   'sugar',
#   'baking powder'],
#  ['butter milk', 'yogurt', 'honey', 'soda', 'detergent'],
#  ['hamburger meat',
#   'citrus fruit',
#   'onions',
#   'rolls/buns',
#   'bottled water',
#   'dental care'],
#  ['pasta', 'popcorn'],
#  ['other vegetables',
#   'whole milk',
#   'meat spreads',
#   'cake bar',
#   'chocolate',
#   'shopping bags'],
#  ['sausage',
#   'pork',
#   'citrus fruit',
#   'dessert',
#   'white bread',
#   'dishes',
#   'candles'],
#  ['rolls/buns'],
#  ['grapes', 'other vegetables', 'curd', 'dessert', 'yogurt', 'napkins'],
#  ['root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'beverages',
#   'soft cheese',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'bottled beer'],
#  ['coffee', 'shopping bags'],
#  ['popcorn'],
#  ['whole milk', 'rolls/buns', 'sugar', 'bottled water', 'soda'],
#  ['tropical fruit',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'snack products'],
#  ['beef', 'herbs', 'flour', 'cling film/bags', 'flower soil/fertilizer'],
#  ['whole milk', 'butter', 'dessert', 'rolls/buns'],
#  ['frankfurter', 'soda', 'chewing gum'],
#  ['tropical fruit', 'specialty cheese', 'bottled water'],
#  ['canned beer'],
#  ['finished products',
#   'other vegetables',
#   'frozen vegetables',
#   'bottled beer'],
#  ['beverages', 'soda'],
#  ['hamburger meat', 'root vegetables', 'whole milk'],
#  ['whole milk', 'pastry', 'long life bakery product'],
#  ['finished products', 'white wine', 'shopping bags'],
#  ['other vegetables'],
#  ['ham',
#   'tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'white bread',
#   'brown bread',
#   'fruit/vegetable juice',
#   'bottled beer'],
#  ['other vegetables'],
#  ['curd', 'butter milk', 'cocoa drinks', 'salty snack', 'popcorn'],
#  ['bottled beer'],
#  ['curd',
#   'dessert',
#   'soda',
#   'salty snack',
#   'waffles',
#   'cake bar',
#   'chocolate',
#   'shopping bags'],
#  ['whole milk', 'cream cheese', 'cereals', 'dog food'],
#  ['whole milk', 'salt'],
#  ['dessert', 'ice cream'],
#  ['sausage', 'soft cheese', 'coffee'],
#  ['other vegetables', 'bottled water', 'waffles', 'dishes', 'shopping bags'],
#  ['ham', 'whole milk', 'rolls/buns'],
#  ['other vegetables', 'ice cream'],
#  ['other vegetables', 'bottled water'],
#  ['soda', 'bottled beer', 'white wine', 'prosecco'],
#  ['herbs', 'candy'],
#  ['frankfurter',
#   'ham',
#   'tropical fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'soft cheese',
#   'sliced cheese',
#   'cream cheese',
#   'frozen meals',
#   'frozen fish',
#   'domestic eggs',
#   'white bread',
#   'sugar',
#   'cereals',
#   'fruit/vegetable juice',
#   'bottled beer',
#   'waffles'],
#  ['rolls/buns', 'canned beer'],
#  ['curd',
#   'cream cheese',
#   'semi-finished bread',
#   'zwieback',
#   'cake bar',
#   'specialty bar',
#   'shopping bags'],
#  ['frankfurter',
#   'tropical fruit',
#   'whole milk',
#   'spread cheese',
#   'margarine',
#   'shopping bags'],
#  ['other vegetables'],
#  ['dog food'],
#  ['specialty bar'],
#  ['curd', 'salt', 'liquor (appetizer)', 'detergent', 'shopping bags'],
#  ['frankfurter', 'rolls/buns'],
#  ['soda'],
#  ['beef',
#   'berries',
#   'root vegetables',
#   'whole milk',
#   'dessert',
#   'spread cheese',
#   'brown bread'],
#  ['canned beer'],
#  ['pork', 'beef', 'pip fruit', 'herbs', 'spices'],
#  ['frankfurter', 'citrus fruit', 'UHT-milk', 'margarine', 'sugar'],
#  ['sausage', 'bottled beer', 'liquor (appetizer)'],
#  ['canned beer'],
#  ['specialty chocolate'],
#  ['curd', 'rolls/buns'],
#  ['canned beer'],
#  ['whole milk', 'bottled water', 'newspapers'],
#  ['rolls/buns', 'chewing gum'],
#  ['pork', 'root vegetables', 'other vegetables', 'whole milk', 'dishes'],
#  ['citrus fruit', 'pastry'],
#  ['potted plants'],
#  ['rolls/buns', 'pastry', 'soda'],
#  ['butter',
#   'yogurt',
#   'bottled water',
#   'soda',
#   'make up remover',
#   'hygiene articles'],
#  ['condensed milk', 'sugar', 'coffee', 'shopping bags'],
#  ['sausage', 'other vegetables', 'yogurt', 'soda', 'shopping bags'],
#  ['whole milk', 'beverages', 'UHT-milk', 'soda'],
#  ['sausage', 'pork', 'beef', 'whole milk', 'rolls/buns', 'margarine'],
#  ['beverages'],
#  ['beverages', 'specialty bar'],
#  ['bottled water', 'fruit/vegetable juice'],
#  ['newspapers'],
#  ['cleaner', 'female sanitary products'],
#  ['sausage', 'soda', 'newspapers', 'shopping bags'],
#  ['newspapers'],
#  ['sausage',
#   'beef',
#   'citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'butter milk',
#   'whipped/sour cream',
#   'beverages',
#   'hard cheese',
#   'rolls/buns',
#   'dish cleaner',
#   'cookware'],
#  ['misc. beverages', 'newspapers'],
#  ['white wine'],
#  ['sausage',
#   'sliced cheese',
#   'rolls/buns',
#   'soda',
#   'canned beer',
#   'shopping bags'],
#  ['meat', 'curd', 'bottled beer', 'cake bar'],
#  ['frankfurter',
#   'meat',
#   'tropical fruit',
#   'onions',
#   'oil',
#   'baking powder',
#   'tea',
#   'cling film/bags'],
#  ['ice cream', 'rolls/buns', 'canned beer'],
#  ['canned beer'],
#  ['tropical fruit',
#   'berries',
#   'root vegetables',
#   'other vegetables',
#   'bottled water',
#   'shopping bags'],
#  ['meat',
#   'citrus fruit',
#   'other vegetables',
#   'curd',
#   'dessert',
#   'butter milk',
#   'beverages',
#   'cream cheese',
#   'rolls/buns',
#   'brown bread',
#   'tea',
#   'bottled water'],
#  ['whole milk', 'mustard', 'bottled water'],
#  ['sausage',
#   'beef',
#   'beverages',
#   'sliced cheese',
#   'rolls/buns',
#   'spices',
#   'house keeping products',
#   'flower (seeds)'],
#  ['frankfurter',
#   'sausage',
#   'root vegetables',
#   'butter',
#   'curd',
#   'sliced cheese',
#   'rolls/buns',
#   'salty snack',
#   'long life bakery product'],
#  ['meat', 'other vegetables', 'butter', 'rolls/buns'],
#  ['root vegetables',
#   'beverages',
#   'Instant food products',
#   'pickled vegetables',
#   'detergent'],
#  ['root vegetables',
#   'herbs',
#   'other vegetables',
#   'whole milk',
#   'sliced cheese',
#   'rolls/buns'],
#  ['whole milk', 'whipped/sour cream', 'semi-finished bread', 'margarine'],
#  ['citrus fruit',
#   'whole milk',
#   'curd',
#   'dessert',
#   'yogurt',
#   'whipped/sour cream',
#   'frozen dessert',
#   'rolls/buns',
#   'salt',
#   'sugar',
#   'cereals',
#   'canned vegetables',
#   'canned fish',
#   'skin care',
#   'hygiene articles',
#   'napkins'],
#  ['citrus fruit',
#   'curd',
#   'pastry',
#   'margarine',
#   'sugar',
#   'candy',
#   'newspapers'],
#  ['other vegetables',
#   'whole milk',
#   'bottled water',
#   'soda',
#   'misc. beverages',
#   'bottled beer',
#   'red/blush wine',
#   'napkins'],
#  ['citrus fruit', 'whole milk', 'rolls/buns'],
#  ['sausage', 'oil', 'hygiene articles', 'napkins'],
#  ['frankfurter',
#   'beef',
#   'hamburger meat',
#   'grapes',
#   'root vegetables',
#   'whole milk',
#   'butter',
#   'frozen dessert',
#   'potato products',
#   'bottled water',
#   'bottled beer'],
#  ['hard cheese', 'rolls/buns', 'bottled water', 'newspapers'],
#  ['cream cheese', 'rolls/buns', 'soda', 'chocolate'],
#  ['turkey', 'beef', 'frozen vegetables', 'dishes', 'photo/film'],
#  ['pork',
#   'other vegetables',
#   'whipped/sour cream',
#   'rolls/buns',
#   'soda',
#   'shopping bags'],
#  ['whole milk', 'beverages'],
#  ['rolls/buns', 'soda'],
#  ['sausage',
#   'pip fruit',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'sliced cheese',
#   'rolls/buns',
#   'bottled water',
#   'hygiene articles'],
#  ['ice cream'],
#  ['liquor'],
#  ['pip fruit', 'other vegetables', 'fruit/vegetable juice'],
#  ['root vegetables', 'other vegetables', 'yogurt'],
#  ['soda'],
#  ['soda'],
#  ['sausage',
#   'citrus fruit',
#   'tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'bottled water',
#   'soda',
#   'chocolate',
#   'newspapers'],
#  ['root vegetables', 'whole milk', 'pet care', 'detergent'],
#  ['pork',
#   'berries',
#   'root vegetables',
#   'other vegetables',
#   'pastry',
#   'specialty bar'],
#  ['pork'],
#  ['chocolate'],
#  ['fruit/vegetable juice'],
#  ['pickled vegetables', 'coffee'],
#  ['bottled water'],
#  ['frankfurter',
#   'sausage',
#   'butter',
#   'whipped/sour cream',
#   'rolls/buns',
#   'margarine',
#   'spices'],
#  ['tropical fruit',
#   'pip fruit',
#   'onions',
#   'other vegetables',
#   'whole milk',
#   'domestic eggs',
#   'sugar',
#   'soups',
#   'tea',
#   'soda',
#   'hygiene articles',
#   'napkins'],
#  ['canned beer'],
#  ['root vegetables'],
#  ['meat', 'citrus fruit', 'berries', 'root vegetables', 'whole milk', 'soda'],
#  ['frankfurter',
#   'rolls/buns',
#   'bottled water',
#   'fruit/vegetable juice',
#   'hygiene articles'],
#  ['tropical fruit', 'margarine', 'rum'],
#  ['tropical fruit',
#   'root vegetables',
#   'herbs',
#   'whole milk',
#   'butter milk',
#   'whipped/sour cream',
#   'flour',
#   'hygiene articles'],
#  ['citrus fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'cream cheese',
#   'domestic eggs',
#   'brown bread',
#   'margarine',
#   'baking powder',
#   'waffles'],
#  ['hamburger meat',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'rolls/buns',
#   'pastry',
#   'semi-finished bread',
#   'margarine',
#   'bottled water',
#   'fruit/vegetable juice'],
#  ['chicken',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'whipped/sour cream',
#   'rolls/buns',
#   'pasta',
#   'soda',
#   'waffles'],
#  ['chicken',
#   'citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'frozen fish',
#   'rolls/buns'],
#  ['frankfurter',
#   'citrus fruit',
#   'onions',
#   'other vegetables',
#   'whole milk',
#   'rolls/buns',
#   'sugar',
#   'soda'],
#  ['canned beer'],
#  ['turkey', 'pip fruit', 'salad dressing', 'pastry'],
#  ['packaged fruit/vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'domestic eggs',
#   'brown bread',
#   'mustard',
#   'pickled vegetables',
#   'bottled water',
#   'misc. beverages'],
#  ['pasta'],
#  ['citrus fruit', 'tropical fruit'],
#  ['sausage',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'brown bread',
#   'potted plants'],
#  ['whole milk', 'frozen meals', 'pastry', 'fruit/vegetable juice', 'waffles'],
#  ['canned beer'],
#  ['citrus fruit', 'sugar', 'sauces'],
#  ['liquor (appetizer)'],
#  ['citrus fruit',
#   'other vegetables',
#   'rolls/buns',
#   'salty snack',
#   'shopping bags'],
#  ['sausage'],
#  ['chicken',
#   'other vegetables',
#   'whole milk',
#   'vinegar',
#   'oil',
#   'bottled water',
#   'canned beer',
#   'napkins',
#   'newspapers'],
#  ['hamburger meat',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'whipped/sour cream',
#   'specialty cheese',
#   'flour',
#   'margarine'],
#  ['sausage', 'pork', 'other vegetables', 'dessert', 'yogurt', 'oil', 'soda'],
#  ['beef',
#   'berries',
#   'root vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'abrasive cleaner'],
#  ['citrus fruit', 'packaged fruit/vegetables', 'yogurt', 'bottled water'],
#  ['UHT-milk', 'coffee'],
#  ['candy'],
#  ['newspapers'],
#  ['beef', 'citrus fruit', 'other vegetables', 'yogurt'],
#  ['sausage', 'rolls/buns'],
#  ['frankfurter',
#   'beef',
#   'root vegetables',
#   'curd',
#   'dessert',
#   'yogurt',
#   'soft cheese',
#   'rolls/buns',
#   'mustard',
#   'pickled vegetables',
#   'canned beer',
#   'hygiene articles',
#   'napkins'],
#  ['canned beer'],
#  ['bottled beer'],
#  ['onions', 'soda', 'chewing gum', 'chocolate', 'newspapers'],
#  ['tropical fruit',
#   'packaged fruit/vegetables',
#   'cream cheese',
#   'white bread',
#   'candy'],
#  ['bottled water', 'white wine'],
#  ['beef', 'white bread', 'pastry', 'pasta', 'soap'],
#  ['sausage',
#   'chicken',
#   'tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'yogurt',
#   'candy',
#   'abrasive cleaner',
#   'cleaner'],
#  ['hair spray'],
#  ['chicken',
#   'whole milk',
#   'spices',
#   'long life bakery product',
#   'shopping bags'],
#  ['pork', 'citrus fruit', 'brown bread', 'pastry', 'sugar', 'cat food'],
#  ['ice cream'],
#  ['meat', 'hard cheese', 'bottled beer'],
#  ['other vegetables', 'yogurt', 'brown bread', 'instant coffee'],
#  ['bottled water', 'cake bar'],
#  ['tropical fruit', 'soda', 'salty snack'],
#  ['photo/film'],
#  ['sausage',
#   'citrus fruit',
#   'yogurt',
#   'coffee',
#   'soda',
#   'canned beer',
#   'dishes'],
#  ['grapes', 'root vegetables'],
#  ['domestic eggs', 'brown bread', 'photo/film'],
#  ['rolls/buns', 'canned fish', 'canned beer'],
#  ['tropical fruit', 'whole milk'],
#  ['chicken'],
#  ['frankfurter', 'other vegetables', 'yogurt', 'brown bread', 'bottled water'],
#  ['berries',
#   'root vegetables',
#   'other vegetables',
#   'curd',
#   'butter milk',
#   'cream cheese',
#   'roll products',
#   'margarine',
#   'misc. beverages',
#   'specialty chocolate',
#   'detergent'],
#  ['margarine', 'hygiene articles'],
#  ['tropical fruit', 'yogurt', 'rolls/buns', 'soda', 'shopping bags'],
#  ['ham',
#   'other vegetables',
#   'whipped/sour cream',
#   'hard cheese',
#   'rolls/buns',
#   'soda',
#   'misc. beverages',
#   'chocolate',
#   'candy'],
#  ['hamburger meat', 'white bread', 'salty snack'],
#  ['yogurt', 'mayonnaise', 'rolls/buns', 'soda', 'napkins'],
#  ['soda', 'specialty chocolate'],
#  ['yogurt'],
#  ['soda'],
#  ['bottled water'],
#  ['sausage', 'meat', 'hamburger meat', 'rubbing alcohol'],
#  ['citrus fruit',
#   'pip fruit',
#   'beverages',
#   'hard cheese',
#   'pet care',
#   'soda',
#   'fruit/vegetable juice',
#   'waffles'],
#  ['shopping bags'],
#  ['newspapers'],
#  ['frankfurter',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'frozen potato products',
#   'zwieback',
#   'specialty bar',
#   'dish cleaner'],
#  ['sausage', 'citrus fruit', 'whole milk', 'canned beer'],
#  ['frankfurter', 'rolls/buns'],
#  ['salt', 'salty snack', 'cookware'],
#  ['oil'],
#  ['curd',
#   'beverages',
#   'cream cheese',
#   'rolls/buns',
#   'pastry',
#   'soda',
#   'cake bar',
#   'chewing gum'],
#  ['other vegetables', 'butter', 'specialty chocolate'],
#  ['citrus fruit'],
#  ['frankfurter', 'whole milk', 'butter milk'],
#  ['root vegetables',
#   'whole milk',
#   'butter',
#   'processed cheese',
#   'mayonnaise',
#   'salty snack'],
#  ['tropical fruit', 'whole milk', 'frozen meals', 'bottled beer'],
#  ['beef', 'hamburger meat', 'pip fruit'],
#  ['berries', 'whipped/sour cream', 'cereals', 'waffles', 'shopping bags'],
#  ['canned beer'],
#  ['whipped/sour cream', 'canned beer', 'red/blush wine'],
#  ['root vegetables',
#   'domestic eggs',
#   'margarine',
#   'chocolate marshmallow',
#   'candy'],
#  ['whole milk', 'soda'],
#  ['beef'],
#  ['frozen vegetables'],
#  ['rolls/buns', 'bottled beer'],
#  ['whole milk', 'hygiene articles'],
#  ['whole milk'],
#  ['citrus fruit', 'whole milk', 'curd', 'soft cheese'],
#  ['pastry', 'fruit/vegetable juice'],
#  ['frankfurter',
#   'sausage',
#   'pork',
#   'pip fruit',
#   'butter',
#   'processed cheese',
#   'white bread',
#   'brown bread'],
#  ['tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'domestic eggs'],
#  ['frankfurter',
#   'sausage',
#   'root vegetables',
#   'yogurt',
#   'whipped/sour cream',
#   'pastry',
#   'napkins'],
#  ['berries',
#   'root vegetables',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'curd',
#   'curd cheese',
#   'cat food',
#   'specialty bar',
#   'detergent'],
#  ['rolls/buns', 'brown bread', 'pastry', 'coffee', 'bottled beer'],
#  ['root vegetables',
#   'packaged fruit/vegetables',
#   'curd',
#   'dessert',
#   'frozen vegetables',
#   'specialty fat',
#   'coffee'],
#  ['yogurt'],
#  ['other vegetables', 'bottled water'],
#  ['berries', 'white bread'],
#  ['berries', 'coffee'],
#  ['other vegetables', 'butter milk', 'frozen meals', 'bottled water'],
#  ['rolls/buns', 'newspapers'],
#  ['ham',
#   'citrus fruit',
#   'whole milk',
#   'whipped/sour cream',
#   'rolls/buns',
#   'pastry',
#   'waffles',
#   'hygiene articles'],
#  ['whole milk', 'frozen dessert', 'salty snack', 'napkins'],
#  ['tropical fruit', 'butter milk', 'rolls/buns', 'bottled water'],
#  ['bottled water'],
#  ['butter milk', 'yogurt'],
#  ['newspapers'],
#  ['coffee'],
#  ['bottled beer', 'liquor'],
#  ['onions',
#   'butter',
#   'whipped/sour cream',
#   'hard cheese',
#   'frozen vegetables',
#   'pasta',
#   'specialty fat',
#   'syrup',
#   'candy',
#   'napkins',
#   'cling film/bags'],
#  ['hamburger meat',
#   'hard cheese',
#   'frozen meals',
#   'pasta',
#   'dog food',
#   'salty snack',
#   'shopping bags'],
#  ['sausage',
#   'liver loaf',
#   'other vegetables',
#   'cream cheese',
#   'pastry',
#   'soap',
#   'shopping bags'],
#  ['hard cheese', 'pastry', 'napkins'],
#  ['sausage', 'tropical fruit', 'condensed milk', 'rolls/buns'],
#  ['hamburger meat'],
#  ['onions', 'whole milk', 'beverages', 'frozen dessert'],
#  ['coffee'],
#  ['shopping bags'],
#  ['yogurt', 'rolls/buns', 'pastry', 'bottled water', 'soda', 'shopping bags'],
#  ['soda'],
#  ['sliced cheese'],
#  ['sausage', 'whole milk', 'coffee'],
#  ['yogurt', 'chocolate'],
#  ['domestic eggs', 'rolls/buns', 'dish cleaner', 'hygiene articles'],
#  ['whole milk'],
#  ['meat', 'other vegetables', 'whole milk', 'whipped/sour cream'],
#  ['dish cleaner', 'bathroom cleaner', 'hygiene articles', 'napkins'],
#  ['other vegetables', 'red/blush wine'],
#  ['whole milk',
#   'butter milk',
#   'yogurt',
#   'sliced cheese',
#   'rolls/buns',
#   'sweet spreads',
#   'coffee',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'shopping bags'],
#  ['other vegetables', 'whole milk', 'rolls/buns', 'Instant food products'],
#  ['tropical fruit', 'other vegetables'],
#  ['baking powder', 'bottled water', 'salty snack', 'chewing gum'],
#  ['specialty bar'],
#  ['ice cream'],
#  ['frankfurter', 'yogurt'],
#  ['canned beer'],
#  ['bottled water'],
#  ['other vegetables',
#   'whole milk',
#   'rolls/buns',
#   'margarine',
#   'bottled water',
#   'bottled beer'],
#  ['citrus fruit',
#   'tropical fruit',
#   'onions',
#   'other vegetables',
#   'shopping bags'],
#  ['sausage',
#   'ham',
#   'hamburger meat',
#   'whole milk',
#   'soda',
#   'softener',
#   'newspapers'],
#  ['domestic eggs', 'rolls/buns', 'specialty bar', 'napkins'],
#  ['pork',
#   'citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'curd',
#   'hygiene articles'],
#  ['specialty cheese',
#   'frozen vegetables',
#   'coffee',
#   'soda',
#   'fruit/vegetable juice',
#   'salty snack'],
#  ['pork',
#   'citrus fruit',
#   'pip fruit',
#   'yogurt',
#   'fruit/vegetable juice',
#   'sparkling wine'],
#  ['beef', 'berries', 'whipped/sour cream', 'domestic eggs', 'rolls/buns'],
#  ['other vegetables', 'pet care'],
#  ['chicken', 'yogurt', 'sliced cheese', 'rolls/buns', 'chewing gum', 'dishes'],
#  ['soda', 'chewing gum'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['bottled beer'],
#  ['root vegetables', 'pastry', 'bottled water', 'male cosmetics'],
#  ['pastry'],
#  ['berries', 'pet care', 'cake bar', 'shopping bags'],
#  ['citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'yogurt',
#   'canned vegetables',
#   'bottled water',
#   'soda',
#   'softener'],
#  ['whole milk', 'oil', 'canned fruit', 'fruit/vegetable juice'],
#  ['soda', 'misc. beverages'],
#  ['bottled water', 'soda'],
#  ['tropical fruit', 'other vegetables', 'rolls/buns'],
#  ['salty snack'],
#  ['bottled water', 'canned beer'],
#  ['chocolate'],
#  ['citrus fruit', 'UHT-milk', 'cream cheese', 'frozen vegetables'],
#  ['bottled water', 'canned beer', 'male cosmetics'],
#  ['onions', 'other vegetables', 'pastry', 'bottled water', 'soda', 'napkins'],
#  ['dessert', 'oil', 'cat food', 'soda'],
#  ['beef',
#   'other vegetables',
#   'whole milk',
#   'frozen potato products',
#   'rolls/buns',
#   'oil',
#   'margarine',
#   'coffee',
#   'dental care',
#   'hygiene articles',
#   'newspapers'],
#  ['rolls/buns',
#   'zwieback',
#   'bottled water',
#   'misc. beverages',
#   'bottled beer',
#   'canned beer',
#   'brandy'],
#  ['beef',
#   'tropical fruit',
#   'root vegetables',
#   'onions',
#   'other vegetables',
#   'instant coffee',
#   'soda'],
#  ['soda'],
#  ['coffee', 'hygiene articles'],
#  ['rolls/buns', 'brown bread', 'bottled water'],
#  ['pork',
#   'beef',
#   'hamburger meat',
#   'other vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'rolls/buns',
#   'margarine',
#   'shopping bags'],
#  ['soda',
#   'canned beer',
#   'liquor (appetizer)',
#   'hygiene articles',
#   'napkins',
#   'newspapers'],
#  ['sausage', 'ham', 'other vegetables', 'ice cream', 'white bread'],
#  ['beef', 'root vegetables', 'other vegetables', 'rolls/buns', 'sugar'],
#  ['whole milk', 'butter', 'bottled water', 'bottled beer'],
#  ['pork', 'ice cream', 'hygiene articles', 'house keeping products'],
#  ['berries',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'ice cream',
#   'fruit/vegetable juice',
#   'salty snack',
#   'specialty bar'],
#  ['sausage',
#   'other vegetables',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'rolls/buns',
#   'roll products'],
#  ['bottled water', 'misc. beverages', 'cling film/bags'],
#  ['tropical fruit',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'hard cheese',
#   'frozen dessert',
#   'rice',
#   'bottled water'],
#  ['herbs', 'bottled water'],
#  ['yogurt', 'rolls/buns'],
#  ['Instant food products'],
#  ['specialty chocolate'],
#  ['coffee'],
#  ['bottled beer', 'liquor'],
#  ['beef', 'root vegetables'],
#  ['whole milk', 'honey', 'waffles'],
#  ['frankfurter', 'rolls/buns', 'pastry', 'snack products', 'specialty bar'],
#  ['frankfurter',
#   'sausage',
#   'liver loaf',
#   'root vegetables',
#   'curd',
#   'frozen vegetables',
#   'rolls/buns',
#   'semi-finished bread',
#   'hygiene articles',
#   'photo/film'],
#  ['other vegetables', 'whole milk', 'cream cheese'],
#  ['frankfurter',
#   'root vegetables',
#   'pickled vegetables',
#   'soda',
#   'seasonal products'],
#  ['whole milk', 'rolls/buns', 'newspapers'],
#  ['frankfurter', 'margarine', 'dental care'],
#  ['other vegetables', 'salty snack'],
#  ['bottled water', 'shopping bags'],
#  ['pork',
#   'onions',
#   'whole milk',
#   'butter',
#   'rolls/buns',
#   'pastry',
#   'rum',
#   'hygiene articles'],
#  ['bottled water'],
#  ['other vegetables',
#   'whipped/sour cream',
#   'specialty cheese',
#   'domestic eggs'],
#  ['hamburger meat', 'whole milk', 'curd', 'pasta', 'canned beer'],
#  ['hamburger meat', 'citrus fruit', 'other vegetables'],
#  ['shopping bags'],
#  ['whole milk', 'cream cheese', 'soda', 'fruit/vegetable juice'],
#  ['ice cream'],
#  ['pastry', 'bottled water'],
#  ['ham',
#   'pip fruit',
#   'whole milk',
#   'curd',
#   'dessert',
#   'butter milk',
#   'whipped/sour cream',
#   'sliced cheese',
#   'cream cheese',
#   'white bread',
#   'coffee',
#   'long life bakery product',
#   'chocolate',
#   'baby cosmetics'],
#  ['frankfurter', 'soda'],
#  ['sausage',
#   'turkey',
#   'beef',
#   'root vegetables',
#   'domestic eggs',
#   'rolls/buns',
#   'flour',
#   'rice',
#   'organic products',
#   'misc. beverages',
#   'napkins'],
#  ['bottled beer'],
#  ['bottled water', 'bottled beer', 'napkins'],
#  ['meat',
#   'other vegetables',
#   'hard cheese',
#   'frozen meals',
#   'bottled water',
#   'soda'],
#  ['dessert', 'candy'],
#  ['other vegetables',
#   'packaged fruit/vegetables',
#   'UHT-milk',
#   'bottled water'],
#  ['beverages', 'rolls/buns', 'soda'],
#  ['ham', 'mustard', 'canned fish'],
#  ['specialty bar'],
#  ['brown bread', 'soda', 'salty snack', 'shopping bags'],
#  ['whole milk', 'cream cheese', 'coffee'],
#  ['rolls/buns', 'pastry', 'red/blush wine'],
#  ['bottled beer', 'nut snack'],
#  ['pet care', 'bottled beer'],
#  ['citrus fruit', 'other vegetables', 'soda'],
#  ['pork', 'other vegetables', 'frozen vegetables', 'hygiene articles'],
#  ['other vegetables', 'shopping bags'],
#  ['white wine', 'detergent'],
#  ['whole milk', 'dessert', 'bottled water'],
#  ['pip fruit', 'white wine', 'shopping bags'],
#  ['sugar', 'soda', 'bottled beer'],
#  ['tropical fruit',
#   'pip fruit',
#   'rolls/buns',
#   'coffee',
#   'fruit/vegetable juice',
#   'candy'],
#  ['root vegetables',
#   'cream cheese',
#   'spread cheese',
#   'frozen dessert',
#   'white bread',
#   'bottled water',
#   'soda',
#   'misc. beverages',
#   'fruit/vegetable juice',
#   'bottled beer'],
#  ['soda', 'misc. beverages'],
#  ['whole milk', 'curd'],
#  ['tropical fruit',
#   'other vegetables',
#   'yogurt',
#   'bottled water',
#   'male cosmetics'],
#  ['white bread', 'brown bread'],
#  ['brown bread', 'sugar', 'hygiene articles'],
#  ['tropical fruit',
#   'root vegetables',
#   'coffee',
#   'bottled water',
#   'red/blush wine',
#   'candy',
#   'house keeping products',
#   'shopping bags'],
#  ['domestic eggs'],
#  ['coffee', 'detergent', 'hygiene articles', 'photo/film'],
#  ['soda'],
#  ['whole milk'],
#  ['bottled beer'],
#  ['pork',
#   'beef',
#   'berries',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'mayonnaise',
#   'frozen fish',
#   'frozen potato products',
#   'oil',
#   'mustard',
#   'cat food',
#   'coffee',
#   'soda',
#   'chocolate',
#   'dish cleaner',
#   'napkins',
#   'newspapers'],
#  ['other vegetables', 'yogurt'],
#  ['yogurt', 'bottled water', 'dishes'],
#  ['sparkling wine'],
#  ['bottled water', 'candy'],
#  ['citrus fruit',
#   'berries',
#   'other vegetables',
#   'butter milk',
#   'sugar',
#   'fruit/vegetable juice',
#   'hygiene articles'],
#  ['hamburger meat',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'rolls/buns'],
#  ['packaged fruit/vegetables', 'seasonal products'],
#  ['other vegetables', 'margarine'],
#  ['soda'],
#  ['whole milk',
#   'yogurt',
#   'frozen potato products',
#   'margarine',
#   'bottled water',
#   'fruit/vegetable juice',
#   'salty snack'],
#  ['herbs', 'yogurt'],
#  ['citrus fruit', 'spread cheese', 'rolls/buns', 'soda'],
#  ['misc. beverages'],
#  ['female sanitary products'],
#  ['soda'],
#  ['tropical fruit',
#   'whole milk',
#   'beverages',
#   'white bread',
#   'pasta',
#   'shopping bags'],
#  ['soda', 'female sanitary products'],
#  ['white bread', 'bottled water', 'soda', 'waffles'],
#  ['coffee', 'chewing gum', 'chocolate marshmallow'],
#  ['tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'honey',
#   'baking powder',
#   'coffee',
#   'red/blush wine',
#   'chocolate marshmallow'],
#  ['pork', 'pip fruit', 'whole milk', 'butter milk'],
#  ['citrus fruit', 'bottled water'],
#  ['frankfurter'],
#  ['frankfurter', 'rolls/buns'],
#  ['frankfurter',
#   'tropical fruit',
#   'pip fruit',
#   'curd',
#   'UHT-milk',
#   'hard cheese',
#   'domestic eggs',
#   'rolls/buns',
#   'hygiene articles',
#   'napkins',
#   'shopping bags'],
#  ['other vegetables'],
#  ['yogurt', 'fruit/vegetable juice', 'newspapers'],
#  ['sausage',
#   'whole milk',
#   'yogurt',
#   'brown bread',
#   'cereals',
#   'bottled water',
#   'soda'],
#  ['whole milk'],
#  ['pip fruit', 'whole milk', 'curd', 'pastry', 'bottled water'],
#  ['whole milk'],
#  ['root vegetables', 'other vegetables'],
#  ['onions', 'fruit/vegetable juice'],
#  ['specialty chocolate'],
#  ['hamburger meat', 'domestic eggs'],
#  ['photo/film'],
#  ['rolls/buns', 'soda', 'snack products', 'newspapers'],
#  ['canned beer'],
#  ['canned beer'],
#  ['other vegetables',
#   'curd',
#   'frozen meals',
#   'frozen potato products',
#   'soda',
#   'bottled beer',
#   'kitchen towels',
#   'candles'],
#  ['canned beer'],
#  ['curd', 'whipped/sour cream', 'rolls/buns', 'zwieback', 'spices'],
#  ['butter', 'fruit/vegetable juice', 'newspapers'],
#  ['other vegetables',
#   'whole milk',
#   'yogurt',
#   'domestic eggs',
#   'bottled water',
#   'soda'],
#  ['whole milk'],
#  ['beef',
#   'tropical fruit',
#   'herbs',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'sliced cheese'],
#  ['sausage', 'rolls/buns'],
#  ['soda'],
#  ['fruit/vegetable juice', 'long life bakery product'],
#  ['rolls/buns',
#   'coffee',
#   'long life bakery product',
#   'detergent',
#   'shopping bags'],
#  ['pip fruit', 'whole milk', 'bottled water', 'candy'],
#  ['frozen vegetables',
#   'bottled beer',
#   'liquor (appetizer)',
#   'chewing gum',
#   'napkins',
#   'newspapers'],
#  ['beverages'],
#  ['hamburger meat',
#   'root vegetables',
#   'other vegetables',
#   'domestic eggs',
#   'roll products',
#   'oil',
#   'margarine',
#   'hygiene articles'],
#  ['root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'fruit/vegetable juice',
#   'white wine'],
#  ['canned beer'],
#  ['frozen vegetables', 'bottled beer'],
#  ['canned beer'],
#  ['newspapers'],
#  ['rolls/buns'],
#  ['hamburger meat', 'UHT-milk', 'salty snack'],
#  ['pip fruit', 'whole milk', 'curd', 'rum'],
#  ['canned beer'],
#  ['grapes',
#   'root vegetables',
#   'frozen vegetables',
#   'domestic eggs',
#   'white wine'],
#  ['root vegetables',
#   'packaged fruit/vegetables',
#   'butter',
#   'whipped/sour cream',
#   'rolls/buns'],
#  ['citrus fruit',
#   'frozen vegetables',
#   'rolls/buns',
#   'canned beer',
#   'salty snack'],
#  ['cling film/bags', 'potted plants'],
#  ['frankfurter',
#   'whole milk',
#   'rolls/buns',
#   'margarine',
#   'baking powder',
#   'bottled beer'],
#  ['whole milk', 'red/blush wine'],
#  ['pork',
#   'tropical fruit',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'hard cheese',
#   'frozen meals',
#   'frozen dessert',
#   'domestic eggs',
#   'cereals',
#   'baking powder',
#   'fruit/vegetable juice',
#   'soap'],
#  ['chicken', 'pastry'],
#  ['sausage', 'dish cleaner', 'dishes'],
#  ['specialty bar'],
#  ['whipped/sour cream', 'pastry', 'specialty bar'],
#  ['root vegetables', 'brown bread'],
#  ['rolls/buns', 'soda'],
#  ['other vegetables', 'bottled beer', 'red/blush wine'],
#  ['citrus fruit',
#   'tropical fruit',
#   'berries',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'bottled water',
#   'rubbing alcohol',
#   'hygiene articles',
#   'napkins'],
#  ['whole milk', 'processed cheese', 'brown bread', 'pastry', 'soda'],
#  ['frankfurter',
#   'sausage',
#   'tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'pastry',
#   'candy'],
#  ['coffee', 'long life bakery product'],
#  ['ham', 'rolls/buns', 'white wine'],
#  ['canned beer'],
#  ['canned beer'],
#  ['canned beer'],
#  ['pip fruit', 'whole milk', 'canned fish'],
#  ['pork',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'white bread',
#   'sugar',
#   'bottled water',
#   'soda'],
#  ['soap'],
#  ['pip fruit', 'butter', 'frozen meals', 'pasta', 'bottled water'],
#  ['beef', 'hamburger meat', 'citrus fruit', 'whole milk', 'mustard', 'soap'],
#  ['sausage',
#   'meat',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'soda',
#   'bottled beer',
#   'chocolate',
#   'newspapers'],
#  ['frozen chicken'],
#  ['soda'],
#  ['tropical fruit',
#   'curd',
#   'yogurt',
#   'rolls/buns',
#   'brown bread',
#   'bottled water',
#   'bottled beer',
#   'seasonal products'],
#  ['other vegetables'],
#  ['beef',
#   'citrus fruit',
#   'curd',
#   'rolls/buns',
#   'oil',
#   'margarine',
#   'specialty bar',
#   'detergent',
#   'newspapers'],
#  ['meat',
#   'pork',
#   'beef',
#   'citrus fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'pickled vegetables'],
#  ['meat',
#   'hamburger meat',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'butter',
#   'newspapers'],
#  ['bottled water',
#   'soda',
#   'red/blush wine',
#   'long life bakery product',
#   'newspapers'],
#  ['rolls/buns'],
#  ['pastry', 'canned beer'],
#  ['pork', 'whole milk', 'pastry', 'sauces'],
#  ['pip fruit',
#   'sliced cheese',
#   'pastry',
#   'white wine',
#   'light bulbs',
#   'newspapers'],
#  ['beef',
#   'citrus fruit',
#   'tropical fruit',
#   'yogurt',
#   'UHT-milk',
#   'frozen vegetables',
#   'rolls/buns',
#   'bottled water',
#   'skin care'],
#  ['beef',
#   'citrus fruit',
#   'berries',
#   'brown bread',
#   'sugar',
#   'coffee',
#   'kitchen towels'],
#  ['rolls/buns', 'spices'],
#  ['citrus fruit',
#   'tropical fruit',
#   'herbs',
#   'whole milk',
#   'butter',
#   'curd',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'canned vegetables',
#   'misc. beverages'],
#  ['meat',
#   'beef',
#   'herbs',
#   'whole milk',
#   'frozen dessert',
#   'rolls/buns',
#   'semi-finished bread',
#   'flour',
#   'oil',
#   'coffee',
#   'potted plants'],
#  ['beverages', 'pastry', 'bottled water'],
#  ['beef', 'citrus fruit', 'other vegetables', 'rolls/buns'],
#  ['ham', 'whole milk', 'white bread', 'margarine', 'hair spray'],
#  ['hamburger meat',
#   'whole milk',
#   'oil',
#   'ketchup',
#   'soups',
#   'Instant food products',
#   'canned fish',
#   'coffee',
#   'bottled beer',
#   'hygiene articles',
#   'newspapers'],
#  ['beef',
#   'citrus fruit',
#   'other vegetables',
#   'butter milk',
#   'sliced cheese',
#   'processed cheese',
#   'rolls/buns',
#   'margarine',
#   'bottled water',
#   'fruit/vegetable juice'],
#  ['beef',
#   'citrus fruit',
#   'whole milk',
#   'domestic eggs',
#   'rolls/buns',
#   'pastry',
#   'roll products',
#   'tea',
#   'fruit/vegetable juice'],
#  ['root vegetables', 'whole milk', 'detergent'],
#  ['citrus fruit',
#   'tropical fruit',
#   'grapes',
#   'other vegetables',
#   'frozen vegetables',
#   'pickled vegetables',
#   'fruit/vegetable juice',
#   'liquor',
#   'rum',
#   'liquor (appetizer)',
#   'candy',
#   'cling film/bags'],
#  ['yogurt', 'bottled water'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'whipped/sour cream',
#   'brown bread',
#   'canned fish',
#   'long life bakery product'],
#  ['frankfurter', 'root vegetables', 'newspapers'],
#  ['beef',
#   'other vegetables',
#   'whole milk',
#   'brown bread',
#   'pastry',
#   'salty snack',
#   'abrasive cleaner',
#   'shopping bags'],
#  ['shopping bags'],
#  ['canned beer'],
#  ['rolls/buns', 'canned beer'],
#  ['other vegetables',
#   'rolls/buns',
#   'meat spreads',
#   'bottled water',
#   'soda',
#   'misc. beverages',
#   'waffles',
#   'chocolate',
#   'candy'],
#  ['hamburger meat',
#   'other vegetables',
#   'yogurt',
#   'rolls/buns',
#   'bottled water'],
#  ['hamburger meat',
#   'citrus fruit',
#   'root vegetables',
#   'rolls/buns',
#   'Instant food products',
#   'canned fish',
#   'bottled water',
#   'soda',
#   'fruit/vegetable juice',
#   'napkins'],
#  ['frankfurter',
#   'sausage',
#   'domestic eggs',
#   'soda',
#   'chewing gum',
#   'shopping bags'],
#  ['bottled beer'],
#  ['tropical fruit', 'domestic eggs', 'rolls/buns', 'pastry'],
#  ['soda'],
#  ['frankfurter',
#   'root vegetables',
#   'onions',
#   'other vegetables',
#   'white bread',
#   'canned beer'],
#  ['chicken',
#   'hamburger meat',
#   'herbs',
#   'whipped/sour cream',
#   'soups',
#   'soda',
#   'canned beer',
#   'dish cleaner',
#   'napkins',
#   'cling film/bags'],
#  ['coffee', 'soda'],
#  ['whole milk'],
#  ['margarine'],
#  ['tropical fruit', 'other vegetables'],
#  ['meat', 'other vegetables'],
#  ['cream cheese', 'bottled water', 'canned beer'],
#  ['newspapers'],
#  ['rolls/buns', 'pastry', 'newspapers'],
#  ['citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'potato products',
#   'fruit/vegetable juice',
#   'long life bakery product'],
#  ['whole milk', 'rolls/buns', 'detergent'],
#  ['frankfurter',
#   'citrus fruit',
#   'butter milk',
#   'UHT-milk',
#   'rolls/buns',
#   'female sanitary products',
#   'shopping bags'],
#  ['ham', 'other vegetables', 'butter', 'whipped/sour cream', 'sugar', 'soda'],
#  ['frankfurter', 'citrus fruit', 'bottled beer', 'salty snack'],
#  ['sausage', 'onions', 'curd', 'yogurt', 'domestic eggs', 'coffee'],
#  ['domestic eggs'],
#  ['whole milk', 'domestic eggs', 'rolls/buns', 'soda'],
#  ['rolls/buns', 'bottled beer', 'newspapers'],
#  ['whole milk', 'hard cheese', 'chocolate marshmallow'],
#  ['sausage', 'root vegetables', 'other vegetables', 'rolls/buns', 'soda'],
#  ['curd', 'butter milk', 'yogurt', 'beverages'],
#  ['bottled water'],
#  ['beef'],
#  ['frankfurter',
#   'hamburger meat',
#   'whole milk',
#   'rolls/buns',
#   'potato products',
#   'mustard',
#   'coffee',
#   'waffles',
#   'chocolate marshmallow',
#   'soap',
#   'newspapers'],
#  ['chicken', 'butter', 'newspapers'],
#  ['sausage',
#   'meat',
#   'tropical fruit',
#   'pip fruit',
#   'pastry',
#   'sugar',
#   'coffee',
#   'candles',
#   'potted plants'],
#  ['pork', 'whole milk', 'whipped/sour cream', 'beverages'],
#  ['yogurt', 'pastry', 'coffee'],
#  ['whole milk',
#   'sliced cheese',
#   'margarine',
#   'cat food',
#   'detergent',
#   'dishes',
#   'shopping bags'],
#  ['frankfurter',
#   'ham',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'pastry',
#   'vinegar',
#   'sugar',
#   'soda',
#   'fruit/vegetable juice',
#   'napkins'],
#  ['beef', 'whole milk', 'brown bread', 'specialty chocolate', 'newspapers'],
#  ['pip fruit',
#   'other vegetables',
#   'butter milk',
#   'cream cheese',
#   'rolls/buns'],
#  ['sausage', 'whole milk', 'rolls/buns', 'coffee', 'chocolate'],
#  ['pastry', 'coffee'],
#  ['chicken', 'beef', 'specialty chocolate'],
#  ['root vegetables',
#   'other vegetables',
#   'whole milk',
#   'sliced cheese',
#   'frozen vegetables',
#   'frozen fish',
#   'frozen dessert',
#   'chocolate'],
#  ['whole milk', 'frozen meals', 'rolls/buns'],
#  ['detergent'],
#  ['rolls/buns', 'canned fish'],
#  ['house keeping products'],
#  ['yogurt', 'salt', 'jam', 'sparkling wine', 'cleaner'],
#  ['tropical fruit', 'curd', 'sliced cheese', 'rolls/buns', 'soda'],
#  ['tropical fruit'],
#  ['curd', 'UHT-milk', 'artif. sweetener', 'dental care'],
#  ['beef', 'berries', 'onions', 'rolls/buns'],
#  ['whole milk',
#   'brown bread',
#   'pasta',
#   'margarine',
#   'bottled water',
#   'napkins',
#   'newspapers'],
#  ['pork', 'UHT-milk', 'bottled water', 'soda', 'canned beer'],
#  ['other vegetables',
#   'curd',
#   'yogurt',
#   'curd cheese',
#   'margarine',
#   'cleaner',
#   'hygiene articles'],
#  ['rolls/buns',
#   'soda',
#   'fruit/vegetable juice',
#   'canned beer',
#   'white wine',
#   'long life bakery product',
#   'shopping bags'],
#  ['frankfurter', 'pip fruit', 'whole milk', 'rolls/buns', 'roll products'],
#  ['yogurt', 'hygiene articles', 'newspapers', 'shopping bags'],
#  ['whole milk', 'curd', 'sliced cheese', 'cat food', 'coffee'],
#  ['bottled water', 'candy'],
#  ['frankfurter', 'beef', 'butter'],
#  ['rolls/buns', 'soda', 'snack products', 'shopping bags'],
#  ['whole milk', 'pastry', 'bottled water', 'hygiene articles'],
#  ['rolls/buns'],
#  ['chicken',
#   'onions',
#   'other vegetables',
#   'whole milk',
#   'brown bread',
#   'white wine',
#   'red/blush wine'],
#  ['tropical fruit', 'onions', 'whole milk', 'butter', 'dishes'],
#  ['sausage',
#   'turkey',
#   'other vegetables',
#   'yogurt',
#   'brown bread',
#   'oil',
#   'hygiene articles',
#   'shopping bags'],
#  ['sausage',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'hard cheese',
#   'soda',
#   'candy',
#   'newspapers'],
#  ['frankfurter',
#   'citrus fruit',
#   'pastry',
#   'margarine',
#   'ready soups',
#   'instant coffee',
#   'shopping bags'],
#  ['UHT-milk',
#   'frozen dessert',
#   'fruit/vegetable juice',
#   'decalcifier',
#   'newspapers'],
#  ['rolls/buns', 'newspapers'],
#  ['canned beer'],
#  ['yogurt', 'specialty bar'],
#  ['whipped/sour cream', 'specialty bar'],
#  ['rolls/buns', 'canned beer'],
#  ['rolls/buns'],
#  ['beverages', 'rolls/buns'],
#  ['rolls/buns'],
#  ['rolls/buns', 'shopping bags'],
#  ['bottled beer'],
#  ['citrus fruit',
#   'curd',
#   'yogurt',
#   'sliced cheese',
#   'rolls/buns',
#   'oil',
#   'bottled water'],
#  ['bottled water', 'soda'],
#  ['pastry'],
#  ['domestic eggs', 'rolls/buns', 'pastry', 'coffee', 'candles'],
#  ['beef', 'pip fruit', 'root vegetables', 'rolls/buns', 'margarine'],
#  ['spread cheese', 'rolls/buns', 'bottled water', 'newspapers'],
#  ['tropical fruit', 'spread cheese', 'rolls/buns', 'soda'],
#  ['packaged fruit/vegetables', 'canned beer', 'candles'],
#  ['whole milk',
#   'yogurt',
#   'bottled beer',
#   'white wine',
#   'salty snack',
#   'napkins'],
#  ['meat',
#   'beef',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'domestic eggs',
#   'rolls/buns'],
#  ['onions',
#   'whole milk',
#   'bottled beer',
#   'liquor (appetizer)',
#   'detergent',
#   'dishes'],
#  ['frankfurter',
#   'grapes',
#   'other vegetables',
#   'butter milk',
#   'UHT-milk',
#   'brown bread',
#   'margarine',
#   'organic products',
#   'bottled water',
#   'soda'],
#  ['beef', 'rolls/buns', 'bottled beer'],
#  ['beef'],
#  ['sausage', 'bottled beer', 'liquor (appetizer)'],
#  ['chicken', 'onions', 'herbs', 'hygiene articles'],
#  ['canned beer'],
#  ['sausage',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'bottled beer',
#   'seasonal products'],
#  ['tropical fruit', 'whole milk', 'curd', 'yogurt', 'whipped/sour cream'],
#  ['frankfurter',
#   'rolls/buns',
#   'soda',
#   'abrasive cleaner',
#   'newspapers',
#   'flower (seeds)'],
#  ['sausage', 'tropical fruit', 'semi-finished bread'],
#  ['beef', 'tropical fruit', 'root vegetables', 'yogurt'],
#  ['tropical fruit', 'pastry', 'flour', 'rum'],
#  ['yogurt'],
#  ['frankfurter', 'rolls/buns', 'mustard'],
#  ['bottled beer'],
#  ['grapes', 'soda'],
#  ['beverages', 'rolls/buns'],
# ...
#   'coffee',
#   'female sanitary products',
#   'hygiene articles',
#   'shopping bags'],
#  ['root vegetables', 'dessert', 'yogurt', 'cream cheese', 'rice'],
#  ['tropical fruit', 'curd', 'rolls/buns', 'organic products', 'newspapers'],
#  ['beef',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'soft cheese',
#   'hard cheese',
#   'domestic eggs',
#   'pasta',
#   'coffee',
#   'candles'],
#  ['chicken', 'pork', 'whole milk', 'butter', 'white bread'],
#  ['citrus fruit',
#   'grapes',
#   'whole milk',
#   'rolls/buns',
#   'pastry',
#   'oil',
#   'margarine',
#   'candles',
#   'newspapers'],
#  ['meat',
#   'beef',
#   'tropical fruit',
#   'pip fruit',
#   'other vegetables',
#   'whipped/sour cream',
#   'soft cheese',
#   'frozen meals',
#   'margarine',
#   'coffee',
#   'fruit/vegetable juice',
#   'potted plants'],
#  ['cream cheese', 'spread cheese', 'rolls/buns'],
#  ['citrus fruit',
#   'herbs',
#   'whole milk',
#   'bottled water',
#   'bottled beer',
#   'potted plants'],
#  ['specialty bar'],
#  ['meat',
#   'other vegetables',
#   'whole milk',
#   'beverages',
#   'rolls/buns',
#   'margarine',
#   'chocolate',
#   'napkins',
#   'newspapers'],
#  ['citrus fruit', 'tropical fruit', 'pip fruit'],
#  ['frankfurter',
#   'beef',
#   'tropical fruit',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'frozen vegetables'],
#  ['citrus fruit', 'whole milk'],
#  ['turkey',
#   'root vegetables',
#   'other vegetables',
#   'curd',
#   'bottled beer',
#   'specialty chocolate'],
#  ['citrus fruit',
#   'onions',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'rolls/buns',
#   'pasta',
#   'mustard',
#   'dog food',
#   'canned beer'],
#  ['sausage', 'domestic eggs'],
#  ['newspapers'],
#  ['whole milk', 'yogurt'],
#  ['yogurt'],
#  ['yogurt'],
#  ['bottled water'],
#  ['berries', 'whole milk', 'whipped/sour cream', 'domestic eggs'],
#  ['packaged fruit/vegetables', 'whole milk', 'rolls/buns', 'pastry'],
#  ['frankfurter', 'soda'],
#  ['nuts/prunes',
#   'whole milk',
#   'semi-finished bread',
#   'jam',
#   'soda',
#   'potted plants',
#   'shopping bags'],
#  ['citrus fruit',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'butter',
#   'whipped/sour cream',
#   'flour',
#   'sugar',
#   'coffee',
#   'soda',
#   'sparkling wine',
#   'dishes'],
#  ['beef',
#   'citrus fruit',
#   'root vegetables',
#   'onions',
#   'curd',
#   'hard cheese',
#   'rolls/buns',
#   'fruit/vegetable juice'],
#  ['whole milk',
#   'yogurt',
#   'frozen vegetables',
#   'coffee',
#   'canned beer',
#   'napkins'],
#  ['other vegetables', 'whipped/sour cream'],
#  ['beef', 'other vegetables'],
#  ['fish',
#   'berries',
#   'other vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'spread cheese',
#   'coffee',
#   'white wine',
#   'red/blush wine'],
#  ['other vegetables',
#   'whole milk',
#   'curd',
#   'frozen vegetables',
#   'domestic eggs',
#   'sugar',
#   'instant coffee',
#   'newspapers'],
#  ['tropical fruit',
#   'berries',
#   'root vegetables',
#   'whole milk',
#   'butter',
#   'yogurt',
#   'whipped/sour cream',
#   'sliced cheese',
#   'hard cheese',
#   'specialty chocolate',
#   'napkins'],
#  ['coffee'],
#  ['sausage',
#   'pork',
#   'other vegetables',
#   'frozen fish',
#   'rolls/buns',
#   'semi-finished bread',
#   'artif. sweetener',
#   'ready soups',
#   'bottled water',
#   'hygiene articles',
#   'newspapers'],
#  ['meat',
#   'root vegetables',
#   'whipped/sour cream',
#   'beverages',
#   'cream cheese',
#   'waffles',
#   'dishes'],
#  ['chicken',
#   'tropical fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'butter',
#   'rolls/buns',
#   'margarine',
#   'sugar',
#   'rum',
#   'long life bakery product',
#   'abrasive cleaner'],
#  ['berries',
#   'whole milk',
#   'whipped/sour cream',
#   'margarine',
#   'organic products',
#   'fruit/vegetable juice',
#   'shopping bags'],
#  ['frozen meals', 'misc. beverages'],
#  ['whipped/sour cream'],
#  ['beef', 'root vegetables', 'bottled beer', 'chocolate', 'shopping bags'],
#  ['chicken',
#   'pork',
#   'other vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'UHT-milk',
#   'domestic eggs',
#   'rolls/buns',
#   'bottled water',
#   'soda',
#   'fruit/vegetable juice',
#   'bottled beer'],
#  ['chicken',
#   'pork',
#   'hamburger meat',
#   'pip fruit',
#   'nuts/prunes',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'spread cheese',
#   'frozen potato products',
#   'brown bread',
#   'Instant food products',
#   'soda',
#   'fruit/vegetable juice',
#   'shopping bags'],
#  ['beef',
#   'tropical fruit',
#   'root vegetables',
#   'herbs',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'hard cheese',
#   'rolls/buns',
#   'brown bread',
#   'bottled water',
#   'bottled beer',
#   'salty snack',
#   'shopping bags'],
#  ['packaged fruit/vegetables', 'pickled vegetables'],
#  ['sugar'],
#  ['frankfurter',
#   'sausage',
#   'beef',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'sliced cheese',
#   'ice cream',
#   'rolls/buns',
#   'soda'],
#  ['berries', 'frozen vegetables', 'pet care', 'instant coffee'],
#  ['bottled water', 'soda', 'chewing gum', 'napkins'],
#  ['sausage',
#   'chicken',
#   'citrus fruit',
#   'berries',
#   'root vegetables',
#   'curd',
#   'beverages',
#   'abrasive cleaner'],
#  ['whole milk',
#   'UHT-milk',
#   'domestic eggs',
#   'soda',
#   'fruit/vegetable juice',
#   'dishes',
#   'newspapers'],
#  ['ice cream', 'rolls/buns'],
#  ['frankfurter', 'citrus fruit', 'tropical fruit', 'rolls/buns'],
#  ['root vegetables',
#   'whole milk',
#   'white bread',
#   'brown bread',
#   'sweet spreads',
#   'dog food',
#   'brandy',
#   'shopping bags'],
#  ['sausage', 'rolls/buns', 'specialty chocolate'],
#  ['sausage',
#   'ham',
#   'citrus fruit',
#   'tropical fruit',
#   'berries',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'sliced cheese',
#   'pastry',
#   'sugar',
#   'baking powder'],
#  ['beef', 'root vegetables', 'whole milk', 'cream cheese'],
#  ['fruit/vegetable juice'],
#  ['sugar', 'hygiene articles'],
#  ['berries', 'whipped/sour cream'],
#  ['yogurt', 'beverages', 'coffee'],
#  ['pork', 'beef'],
#  ['bottled beer', 'shopping bags'],
#  ['curd', 'butter milk', 'yogurt', 'sliced cheese', 'coffee'],
#  ['beef', 'Instant food products', 'canned beer'],
#  ['pork',
#   'berries',
#   'whipped/sour cream',
#   'beverages',
#   'flour',
#   'oil',
#   'soda',
#   'chocolate',
#   'newspapers'],
#  ['white bread'],
#  ['grapes',
#   'whole milk',
#   'processed cheese',
#   'rolls/buns',
#   'white bread',
#   'fruit/vegetable juice'],
#  ['potato products', 'flower (seeds)'],
#  ['root vegetables',
#   'onions',
#   'yogurt',
#   'rolls/buns',
#   'coffee',
#   'bottled water',
#   'dishes'],
#  ['chicken',
#   'hamburger meat',
#   'UHT-milk',
#   'soda',
#   'canned beer',
#   'bathroom cleaner',
#   'newspapers'],
#  ['chicken', 'other vegetables', 'salt'],
#  ['fish', 'cream cheese', 'coffee'],
#  ['canned beer'],
#  ['other vegetables',
#   'whole milk',
#   'frozen meals',
#   'rolls/buns',
#   'brown bread',
#   'napkins'],
#  ['chicken',
#   'pork',
#   'whole milk',
#   'frozen vegetables',
#   'brown bread',
#   'vinegar',
#   'bottled beer',
#   'red/blush wine',
#   'newspapers'],
#  ['other vegetables', 'misc. beverages'],
#  ['tropical fruit', 'whole milk'],
#  ['whole milk', 'cake bar', 'newspapers'],
#  ['beef', 'hamburger meat', 'berries', 'pastry', 'hygiene articles'],
#  ['sausage', 'grapes', 'rolls/buns', 'soda', 'salty snack'],
#  ['whole milk', 'rolls/buns', 'chocolate'],
#  ['rolls/buns', 'soda'],
#  ['citrus fruit', 'tropical fruit', 'pip fruit', 'other vegetables'],
#  ['whole milk',
#   'sliced cheese',
#   'domestic eggs',
#   'artif. sweetener',
#   'bottled water',
#   'soda',
#   'shopping bags'],
#  ['pastry', 'soda', 'bottled beer'],
#  ['tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'soft cheese',
#   'hard cheese',
#   'spread cheese',
#   'curd cheese',
#   'frozen vegetables',
#   'ice cream',
#   'pastry',
#   'coffee',
#   'fruit/vegetable juice',
#   'hygiene articles'],
#  ['sliced cheese', 'pastry', 'newspapers'],
#  ['soda'],
#  ['ham',
#   'citrus fruit',
#   'whole milk',
#   'dessert',
#   'frozen meals',
#   'coffee',
#   'popcorn',
#   'shopping bags'],
#  ['salty snack'],
#  ['whole milk',
#   'curd',
#   'cream cheese',
#   'flour',
#   'coffee',
#   'bottled water',
#   'misc. beverages',
#   'newspapers'],
#  ['root vegetables', 'whipped/sour cream'],
#  ['soda', 'canned beer', 'shopping bags'],
#  ['curd',
#   'roll products',
#   'margarine',
#   'bottled water',
#   'canned beer',
#   'white wine',
#   'dish cleaner'],
#  ['bottled water', 'soda', 'fruit/vegetable juice', 'bottled beer', 'napkins'],
#  ['packaged fruit/vegetables', 'potted plants'],
#  ['tropical fruit',
#   'root vegetables',
#   'frozen vegetables',
#   'ice cream',
#   'bottled water',
#   'cling film/bags'],
#  ['ham',
#   'beef',
#   'grapes',
#   'yogurt',
#   'whipped/sour cream',
#   'domestic eggs',
#   'white bread',
#   'pastry',
#   'bottled water',
#   'fruit/vegetable juice',
#   'white wine',
#   'salty snack',
#   'chocolate',
#   'newspapers',
#   'shopping bags'],
#  ['pork',
#   'citrus fruit',
#   'UHT-milk',
#   'brown bread',
#   'soda',
#   'bottled beer',
#   'canned beer',
#   'long life bakery product'],
#  ['beverages', 'rolls/buns', 'soda', 'misc. beverages', 'liqueur', 'cake bar'],
#  ['sausage', 'rolls/buns', 'soda'],
#  ['sausage',
#   'citrus fruit',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'bottled water',
#   'soda',
#   'napkins'],
#  ['root vegetables',
#   'whole milk',
#   'butter',
#   'yogurt',
#   'cream cheese',
#   'frozen fish',
#   'shopping bags'],
#  ['whole milk', 'cream cheese'],
#  ['frankfurter',
#   'turkey',
#   'root vegetables',
#   'other vegetables',
#   'yogurt',
#   'rolls/buns',
#   'pastry',
#   'ready soups'],
#  ['soda', 'shopping bags'],
#  ['soda', 'bottled beer'],
#  ['frankfurter', 'popcorn'],
#  ['berries',
#   'whole milk',
#   'whipped/sour cream',
#   'pickled vegetables',
#   'detergent',
#   'newspapers'],
#  ['canned beer'],
#  ['frankfurter', 'pork', 'white bread', 'canned vegetables', 'soda'],
#  ['frankfurter',
#   'hamburger meat',
#   'whole milk',
#   'butter',
#   'curd',
#   'flour',
#   'rice',
#   'oil',
#   'sugar',
#   'mustard',
#   'salty snack',
#   'chocolate',
#   'chocolate marshmallow',
#   'dish cleaner',
#   'dental care'],
#  ['berries',
#   'root vegetables',
#   'whole milk',
#   'beverages',
#   'sugar',
#   'soups',
#   'coffee',
#   'shopping bags'],
#  ['frankfurter', 'rolls/buns'],
#  ['newspapers'],
#  ['frozen fish', 'newspapers'],
#  ['tropical fruit', 'newspapers'],
#  ['beef',
#   'grapes',
#   'berries',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'newspapers',
#   'potted plants'],
#  ['rolls/buns',
#   'coffee',
#   'instant coffee',
#   'salty snack',
#   'specialty chocolate'],
#  ['specialty chocolate', 'potted plants'],
#  ['sparkling wine', 'dish cleaner'],
#  ['citrus fruit', 'napkins', 'shopping bags'],
#  ['onions', 'herbs', 'bottled beer'],
#  ['whole milk', 'pastry', 'detergent', 'candles'],
#  ['photo/film'],
#  ['hamburger meat'],
#  ['other vegetables', 'whole milk', 'white bread', 'chewing gum'],
#  ['whole milk', 'rolls/buns', 'shopping bags'],
#  ['pork',
#   'tropical fruit',
#   'grapes',
#   'hard cheese',
#   'soda',
#   'napkins',
#   'shopping bags'],
#  ['tropical fruit',
#   'grapes',
#   'berries',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'dessert',
#   'yogurt',
#   'whipped/sour cream',
#   'ice cream',
#   'pastry',
#   'salt',
#   'baking powder',
#   'bottled water',
#   'misc. beverages',
#   'fruit/vegetable juice',
#   'canned beer',
#   'specialty chocolate',
#   'potted plants'],
#  ['chicken',
#   'pork',
#   'citrus fruit',
#   'other vegetables',
#   'whipped/sour cream',
#   'white bread',
#   'chewing gum',
#   'potted plants'],
#  ['other vegetables', 'chewing gum'],
#  ['sausage', 'bottled water', 'red/blush wine'],
#  ['whole milk', 'whipped/sour cream', 'baking powder'],
#  ['rolls/buns', 'coffee'],
#  ['hygiene articles'],
#  ['ice cream', 'newspapers'],
#  ['curd',
#   'whipped/sour cream',
#   'domestic eggs',
#   'flour',
#   'misc. beverages',
#   'newspapers'],
#  ['whole milk', 'frozen meals', 'newspapers'],
#  ['onions',
#   'whole milk',
#   'dessert',
#   'domestic eggs',
#   'rolls/buns',
#   'white bread',
#   'coffee',
#   'bottled water'],
#  ['finished products',
#   'organic sausage',
#   'sliced cheese',
#   'white bread',
#   'fruit/vegetable juice'],
#  ['salt', 'dog food', 'long life bakery product'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'domestic eggs',
#   'white bread',
#   'brown bread',
#   'canned vegetables',
#   'soda',
#   'fruit/vegetable juice',
#   'rum'],
#  ['other vegetables', 'whole milk', 'yogurt'],
#  ['chocolate'],
#  ['ice cream'],
#  ['tropical fruit', 'oil', 'cat food'],
#  ['frankfurter',
#   'citrus fruit',
#   'whole milk',
#   'yogurt',
#   'sliced cheese',
#   'specialty cheese',
#   'pastry',
#   'fruit/vegetable juice'],
#  ['butter', 'pasta', 'canned fish', 'softener', 'flower (seeds)'],
#  ['other vegetables', 'butter milk', 'frozen fish', 'salty snack'],
#  ['tropical fruit', 'pastry', 'canned beer', 'chocolate'],
#  ['citrus fruit',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'yogurt',
#   'sliced cheese',
#   'rolls/buns',
#   'white bread',
#   'brown bread',
#   'zwieback'],
#  ['UHT-milk', 'salt', 'soda', 'specialty chocolate', 'shopping bags'],
#  ['beef'],
#  ['curd', 'yogurt', 'spread cheese', 'sugar', 'canned vegetables'],
#  ['citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'bottled beer',
#   'salty snack'],
#  ['yogurt', 'brown bread', 'bottled beer', 'white wine'],
#  ['bottled beer', 'liquor', 'red/blush wine'],
#  ['grapes'],
#  ['pork', 'other vegetables', 'soda'],
#  ['sausage',
#   'citrus fruit',
#   'berries',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'whipped/sour cream',
#   'cream cheese',
#   'frozen vegetables',
#   'domestic eggs',
#   'pastry',
#   'margarine',
#   'soups',
#   'canned fish',
#   'chocolate',
#   'candy',
#   'napkins'],
#  ['frankfurter',
#   'chicken',
#   'pork',
#   'tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'yogurt',
#   'UHT-milk',
#   'mayonnaise',
#   'brown bread',
#   'pastry',
#   'flour',
#   'mustard',
#   'coffee',
#   'cocoa drinks',
#   'fruit/vegetable juice',
#   'salty snack',
#   'long life bakery product',
#   'chocolate',
#   'seasonal products'],
#  ['artif. sweetener', 'soda', 'photo/film'],
#  ['frankfurter',
#   'onions',
#   'butter',
#   'processed cheese',
#   'rolls/buns',
#   'coffee',
#   'bottled beer'],
#  ['pip fruit',
#   'root vegetables',
#   'dessert',
#   'yogurt',
#   'domestic eggs',
#   'shopping bags'],
#  ['frankfurter', 'whole milk', 'coffee', 'detergent'],
#  ['whole milk', 'newspapers'],
#  ['domestic eggs', 'hygiene articles', 'photo/film', 'flower soil/fertilizer'],
#  ['packaged fruit/vegetables',
#   'dessert',
#   'mayonnaise',
#   'oil',
#   'soda',
#   'waffles',
#   'chocolate',
#   'flower (seeds)',
#   'shopping bags'],
#  ['chicken',
#   'other vegetables',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'bottled water',
#   'long life bakery product'],
#  ['pork',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'cream cheese',
#   'domestic eggs',
#   'white bread',
#   'sugar',
#   'baking powder',
#   'coffee',
#   'cocoa drinks',
#   'salty snack',
#   'waffles',
#   'candy',
#   'napkins'],
#  ['citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'cream cheese',
#   'pastry',
#   'vinegar',
#   'oil',
#   'coffee',
#   'long life bakery product',
#   'detergent',
#   'cleaner',
#   'napkins',
#   'newspapers'],
#  ['light bulbs'],
#  ['cream cheese', 'margarine', 'tea'],
#  ['sausage',
#   'curd',
#   'frozen meals',
#   'domestic eggs',
#   'cake bar',
#   'seasonal products',
#   'detergent',
#   'cleaner',
#   'house keeping products',
#   'potted plants',
#   'shopping bags'],
#  ['citrus fruit', 'onions'],
#  ['other vegetables', 'whipped/sour cream', 'roll products'],
#  ['chicken',
#   'tropical fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'yogurt',
#   'whipped/sour cream',
#   'hard cheese',
#   'frozen vegetables',
#   'frozen fish',
#   'domestic eggs',
#   'white bread',
#   'rice',
#   'specialty fat',
#   'dog food',
#   'bottled water',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'softener',
#   'napkins',
#   'cling film/bags'],
#  ['ice cream'],
#  ['pork', 'beef', 'ice cream', 'rolls/buns', 'newspapers'],
#  ['pork',
#   'tropical fruit',
#   'other vegetables',
#   'yogurt',
#   'semi-finished bread',
#   'flour',
#   'margarine',
#   'artif. sweetener',
#   'organic products',
#   'chocolate marshmallow'],
#  ...]

# %%
def preprocess_transactions(transactions, min_support):
    item_counts = defaultdict(int)
    for transaction in transactions:
        for item in transaction:
            item_counts[item] += 1

    frequent_items = {item for item, count in item_counts.items() if count >= min_support}
    processed_transactions = []
    for transaction in transactions:
        sorted_transaction = [item for item in transaction if item in frequent_items]
        sorted_transaction.sort(key=lambda item: item_counts[item], reverse=True)
        if sorted_transaction:
            processed_transactions.append(sorted_transaction)
    
    return processed_transactions, item_counts

min_support = 10
processed_transactions, item_counts = preprocess_transactions(transactions, min_support)

# %%
class FPTreeNode:
    def __init__(self, item, count, parent):
        self.item = item
        self.count = count
        self.parent = parent
        self.children = {}
        self.next = None

    def increment(self, count):
        self.count += count

# %%
def construct_fp_tree(transactions):
    root = FPTreeNode(None, 0, None)
    header_table = {}
    for transaction in transactions:
        for item in transaction:
            if item not in header_table:
                header_table[item] = [0, None]
            header_table[item][0] += 1

    for transaction in transactions:
        sorted_items = [item for item in transaction if item in header_table]
        sorted_items.sort(key=lambda item: header_table[item][0], reverse=True)
        current_node = root
        for item in sorted_items:
            if item in current_node.children:
                current_node.children[item].increment(1)
            else:
                new_node = FPTreeNode(item, 1, current_node)
                current_node.children[item] = new_node
                if header_table[item][1] is None:
                    header_table[item][1] = new_node
                else:
                    temp_node = header_table[item][1]
                    while temp_node.next is not None:
                        temp_node = temp_node.next
                    temp_node.next = new_node
            current_node = current_node.children[item]
    return root, header_table

fp_tree, header_table = construct_fp_tree(processed_transactions)

# %%
max_frequent_itemset = max(header_table.items(), key=lambda x: x[1][0])
max_item, (max_count, _) = max_frequent_itemset
transaction_count = sum(1 for t in processed_transactions if max_item in t)

# %%
def find_frequent_patterns(transactions, min_support):
    item_counts = defaultdict(int)
    pair_counts = defaultdict(int)
    for transaction in transactions:
        for item in transaction:
            item_counts[item] += 1
        for pair in combinations(transaction, 2):
            pair_counts[pair] += 1
    return {pair: count for pair, count in pair_counts.items() if count >= min_support}

frequent_patterns = find_frequent_patterns(processed_transactions, min_support)

# %%
print("Most Frequent Itemset:", max_item)
print("Frequency:", max_count)
print("Transaction Count:", transaction_count)
print("Top 5 Frequent Patterns:", sorted(frequent_patterns.items(), key=lambda x: x[1], reverse=True)[:5])
for pattern, count in sorted(frequent_patterns.items(), key=lambda x: x[1], reverse=True):
    print(pattern, "->", count)
# Out:
# Most Frequent Itemset: whole milk
# Frequency: 2513
# Transaction Count: 2513
# Top 5 Frequent Patterns: [(('whole milk', 'other vegetables'), 736), (('whole milk', 'rolls/buns'), 557), (('whole milk', 'yogurt'), 551), (('whole milk', 'root vegetables'), 481), (('other vegetables', 'root vegetables'), 466)]
# ('whole milk', 'other vegetables') -> 736
# ('whole milk', 'rolls/buns') -> 557
# ('whole milk', 'yogurt') -> 551
# ('whole milk', 'root vegetables') -> 481
# ('other vegetables', 'root vegetables') -> 466
# ('other vegetables', 'yogurt') -> 427
# ('other vegetables', 'rolls/buns') -> 419
# ('whole milk', 'tropical fruit') -> 416
# ('whole milk', 'soda') -> 394
# ('rolls/buns', 'soda') -> 377
# ('other vegetables', 'tropical fruit') -> 353
# ('whole milk', 'bottled water') -> 338
# ('rolls/buns', 'yogurt') -> 338
# ('whole milk', 'pastry') -> 327
# ('other vegetables', 'soda') -> 322
# ('whole milk', 'whipped/sour cream') -> 317
# ('rolls/buns', 'sausage') -> 301
# ('whole milk', 'citrus fruit') -> 300
# ('whole milk', 'pip fruit') -> 296
# ('whole milk', 'domestic eggs') -> 295
# ('whole milk', 'sausage') -> 294
# ('yogurt', 'tropical fruit') -> 288
# ('soda', 'bottled water') -> 285
# ('other vegetables', 'whipped/sour cream') -> 284
# ('other vegetables', 'citrus fruit') -> 284
# ('whole milk', 'butter') -> 271
# ('soda', 'yogurt') -> 269
# ('whole milk', 'newspapers') -> 269
# ('other vegetables', 'sausage') -> 265
# ('whole milk', 'fruit/vegetable juice') -> 262
# ('whole milk', 'curd') -> 257
# ('other vegetables', 'pip fruit') -> 257
# ('yogurt', 'root vegetables') -> 254
# ('whole milk', 'brown bread') -> 248
# ('other vegetables', 'bottled water') -> 244
# ('rolls/buns', 'tropical fruit') -> 242
# ('soda', 'shopping bags') -> 242
# ('whole milk', 'shopping bags') -> 241
# ('rolls/buns', 'root vegetables') -> 239
# ('soda', 'sausage') -> 239
# ('rolls/buns', 'bottled water') -> 238
# ('whole milk', 'margarine') -> 238
# ('other vegetables', 'shopping bags') -> 228
# ('yogurt', 'bottled water') -> 226
# ('other vegetables', 'pastry') -> 222
# ('other vegetables', 'domestic eggs') -> 219
# ('whole milk', 'pork') -> 218
# ('soda', 'cake bar') -> 44
# ('pip fruit', 'waffles') -> 44
# ('root vegetables', 'grapes') -> 44
# ('yogurt', 'misc. beverages') -> 44
# ('pork', 'sugar') -> 44
# ('pastry', 'cream cheese') -> 44
# ('pip fruit', 'hamburger meat') -> 44
# ('coffee', 'frozen vegetables') -> 44
# ('curd', 'frozen vegetables') -> 44
# ('shopping bags', 'candy') -> 44
# ('pastry', 'canned beer') -> 44
# ('margarine', 'napkins') -> 44
# ('bottled water', 'cat food') -> 44
# ('whipped/sour cream', 'oil') -> 44
# ('bottled water', 'white bread') -> 43
# ('butter', 'long life bakery product') -> 43
# ('root vegetables', 'detergent') -> 43
# ('shopping bags', 'sliced cheese') -> 43
# ('butter', 'hamburger meat') -> 43
# ('sausage', 'hygiene articles') -> 43
# ('frankfurter', 'curd') -> 43
# ('butter', 'hygiene articles') -> 43
# ('bottled water', 'grapes') -> 43
# ('bottled water', 'salty snack') -> 43
# ('white bread', 'long life bakery product') -> 43
# ('other vegetables', 'potted plants') -> 43
# ('chocolate', 'white bread') -> 42
# ('tropical fruit', 'processed cheese') -> 42
# ('root vegetables', 'candy') -> 42
# ('bottled water', 'long life bakery product') -> 42
# ('tropical fruit', 'semi-finished bread') -> 42
# ('rolls/buns', 'pickled vegetables') -> 42
# ('whipped/sour cream', 'hamburger meat') -> 42
# ('pork', 'chocolate') -> 42
# ('other vegetables', 'pasta') -> 42
# ('tropical fruit', 'hamburger meat') -> 42
# ('pastry', 'specialty bar') -> 42
# ('bottled beer', 'frozen vegetables') -> 42
# ('butter', 'white bread') -> 42
# ('citrus fruit', 'dessert') -> 42
# ('bottled water', 'waffles') -> 42
# ('whipped/sour cream', 'hygiene articles') -> 42
# ('pastry', 'berries') -> 42
# ('citrus fruit', 'waffles') -> 42
# ('other vegetables', 'specialty cheese') -> 42
# ('coffee', 'UHT-milk') -> 42
# ('rolls/buns', 'mustard') -> 42
# ('citrus fruit', 'canned beer') -> 42
# ('shopping bags', 'onions') -> 42
# ('pork', 'curd') -> 42
# ('tropical fruit', 'beverages') -> 42
# ('newspapers', 'UHT-milk') -> 42
# ('shopping bags', 'misc. beverages') -> 42
# ('rolls/buns', 'spread cheese') -> 41
# ('bottled water', 'oil') -> 41
# ('whipped/sour cream', 'ham') -> 41
# ('fruit/vegetable juice', 'sliced cheese') -> 41
# ('fruit/vegetable juice', 'hard cheese') -> 41
# ('pork', 'white bread') -> 41
# ('pip fruit', 'sliced cheese') -> 41
# ('domestic eggs', 'ham') -> 41
# ('canned beer', 'coffee') -> 41
# ('white bread', 'processed cheese') -> 41
# ('pastry', 'ham') -> 41
# ('shopping bags', 'frozen vegetables') -> 41
# ('citrus fruit', 'long life bakery product') -> 41
# ('newspapers', 'waffles') -> 41
# ('soda', 'pickled vegetables') -> 40
# ('soda', 'grapes') -> 40
# ('coffee', 'napkins') -> 40
# ('root vegetables', 'pickled vegetables') -> 40
# ('sausage', 'oil') -> 40
# ('domestic eggs', 'hamburger meat') -> 40
# ('waffles', 'long life bakery product') -> 40
# ('curd', 'long life bakery product') -> 32
# ('curd', 'butter milk') -> 32
# ('pork', 'hamburger meat') -> 32
# ('rolls/buns', 'dishes') -> 32
# ('bottled water', 'red/blush wine') -> 32
# ('margarine', 'long life bakery product') -> 32
# ('sugar', 'baking powder') -> 32
# ('yogurt', 'frozen fish') -> 32
# ('tropical fruit', 'soft cheese') -> 32
# ('shopping bags', 'semi-finished bread') -> 32
# ('frankfurter', 'meat') -> 32
# ('yogurt', 'canned fish') -> 32
# ('pastry', 'semi-finished bread') -> 32
# ('canned beer', 'chicken') -> 32
# ('beef', 'hygiene articles') -> 32
# ('chicken', 'long life bakery product') -> 32
# ('pastry', 'beverages') -> 32
# ('frankfurter', 'butter milk') -> 32
# ('coffee', 'curd') -> 32
# ('coffee', 'hygiene articles') -> 32
# ('domestic eggs', 'flour') -> 32
# ('yogurt', 'seasonal products') -> 32
# ('other vegetables', 'cling film/bags') -> 32
# ('fruit/vegetable juice', 'grapes') -> 32
# ('shopping bags', 'chewing gum') -> 32
# ('pork', 'UHT-milk') -> 32
# ('brown bread', 'onions') -> 32
# ('brown bread', 'hamburger meat') -> 32
# ('other vegetables', 'mustard') -> 32
# ('pork', 'salty snack') -> 32
# ('tropical fruit', 'specialty bar') -> 32
# ('canned beer', 'pip fruit') -> 32
# ('curd', 'flour') -> 31
# ('newspapers', 'sugar') -> 31
# ('butter', 'sugar') -> 31
# ('root vegetables', 'beverages') -> 31
# ('soda', 'spread cheese') -> 31
# ('domestic eggs', 'baking powder') -> 31
# ('newspapers', 'oil') -> 31
# ('frozen vegetables', 'onions') -> 31
# ('sausage', 'grapes') -> 31
# ('brown bread', 'berries') -> 31
# ('frozen vegetables', 'dessert') -> 31
# ('frankfurter', 'waffles') -> 31
# ('citrus fruit', 'hard cheese') -> 31
# ('frankfurter', 'hygiene articles') -> 31
# ('frozen vegetables', 'sugar') -> 31
# ('pork', 'dessert') -> 31
# ('other vegetables', 'packaged fruit/vegetables') -> 31
# ('domestic eggs', 'frozen meals') -> 31
# ('domestic eggs', 'soft cheese') -> 31
# ('butter', 'ham') -> 31
# ('whole milk', 'spread cheese') -> 31
# ('frankfurter', 'UHT-milk') -> 31
# ('frankfurter', 'salty snack') -> 31
# ('other vegetables', 'soups') -> 31
# ('napkins', 'onions') -> 31
# ('whipped/sour cream', 'herbs') -> 31
# ('curd', 'hamburger meat') -> 31
# ('yogurt', 'pasta') -> 31
# ('canned beer', 'napkins') -> 31
# ('pork', 'oil') -> 31
# ('newspapers', 'onions') -> 31
# ('pastry', 'cat food') -> 31
# ('root vegetables', 'roll products') -> 31
# ('rolls/buns', 'cake bar') -> 31
# ('root vegetables', 'processed cheese') -> 31
# ('bottled water', 'frozen meals') -> 31
# ('beef', 'oil') -> 31
# ('beef', 'onions') -> 31
# ('coffee', 'white bread') -> 31
# ('root vegetables', 'rice') -> 31
# ('chocolate', 'cat food') -> 31
# ('whole milk', 'chocolate marshmallow') -> 31
# ('newspapers', 'sliced cheese') -> 31
# ('bottled beer', 'salty snack') -> 31
# ('chicken', 'berries') -> 31
# ('margarine', 'chocolate') -> 31
# ('shopping bags', 'ice cream') -> 31
# ('chocolate', 'specialty chocolate') -> 31
# ('bottled water', 'beverages') -> 30
# ('coffee', 'waffles') -> 30
# ('whipped/sour cream', 'UHT-milk') -> 30
# ('margarine', 'baking powder') -> 30
# ('whole milk', 'candles') -> 30
# ('rolls/buns', 'detergent') -> 30
# ('sausage', 'pickled vegetables') -> 30
# ('margarine', 'dessert') -> 30
# ('frozen vegetables', 'hamburger meat') -> 30
# ('pip fruit', 'hard cheese') -> 30
# ('shopping bags', 'beverages') -> 30
# ('curd', 'salty snack') -> 30
# ('whipped/sour cream', 'soft cheese') -> 30
# ('cream cheese', 'waffles') -> 30
# ('bottled water', 'meat') -> 30
# ('butter', 'meat') -> 30
# ('rolls/buns', 'herbs') -> 30
# ('yogurt', 'canned vegetables') -> 30
# ('margarine', 'hamburger meat') -> 30
# ('bottled water', 'pickled vegetables') -> 30
# ('beef', 'white bread') -> 30
# ('root vegetables', 'misc. beverages') -> 30
# ('shopping bags', 'hard cheese') -> 30
# ('whole milk', 'Instant food products') -> 30
# ('coffee', 'salty snack') -> 30
# ('soda', 'canned vegetables') -> 30
# ('newspapers', 'hygiene articles') -> 30
# ('bottled water', 'herbs') -> 30
# ('frozen vegetables', 'hygiene articles') -> 30
# ('brown bread', 'hygiene articles') -> 30
# ('newspapers', 'meat') -> 30
# ('citrus fruit', 'pickled vegetables') -> 30
# ('hamburger meat', 'Instant food products') -> 30
# ('margarine', 'sliced cheese') -> 30
# ('tropical fruit', 'potted plants') -> 30
# ('shopping bags', 'oil') -> 30
# ('dessert', 'UHT-milk') -> 30
# ('whipped/sour cream', 'grapes') -> 30
# ('pastry', 'oil') -> 30
# ('fruit/vegetable juice', 'meat') -> 30
# ('other vegetables', 'spread cheese') -> 30
# ('napkins', 'sliced cheese') -> 30
# ('canned beer', 'margarine') -> 30
# ('tropical fruit', 'canned beer') -> 30
# ('canned beer', 'chocolate') -> 30
# ('ham', 'processed cheese') -> 30
# ('beef', 'waffles') -> 30
# ('rolls/buns', 'frozen dessert') -> 29
# ('waffles', 'candy') -> 29
# ('bottled water', 'hamburger meat') -> 29
# ('frozen vegetables', 'salty snack') -> 29
# ('coffee', 'hamburger meat') -> 29
# ('domestic eggs', 'misc. beverages') -> 29
# ('pip fruit', 'soft cheese') -> 29
# ('shopping bags', 'cake bar') -> 29
# ('whole milk', 'dog food') -> 29
# ('frankfurter', 'frozen meals') -> 29
# ('whole milk', 'dish cleaner') -> 29
# ('butter', 'salty snack') -> 29
# ('margarine', 'candy') -> 29
# ('whole milk', 'soups') -> 29
# ('curd', 'berries') -> 29
# ('frozen vegetables', 'cream cheese') -> 29
# ('pastry', 'onions') -> 29
# ('beef', 'sugar') -> 29
# ('long life bakery product', 'dessert') -> 29
# ('margarine', 'salty snack') -> 29
# ('pastry', 'processed cheese') -> 29
# ('citrus fruit', 'herbs') -> 29
# ('fruit/vegetable juice', 'processed cheese') -> 29
# ('soda', 'canned fish') -> 29
# ('pork', 'meat') -> 27
# ('butter', 'herbs') -> 27
# ('pip fruit', 'meat') -> 27
# ('chicken', 'cream cheese') -> 27
# ('soda', 'potted plants') -> 27
# ('whipped/sour cream', 'specialty chocolate') -> 27
# ('pastry', 'soft cheese') -> 27
# ('chocolate', 'chicken') -> 27
# ('chocolate', 'hygiene articles') -> 27
# ('whole milk', 'kitchen towels') -> 27
# ('soda', 'soft cheese') -> 27
# ('napkins', 'dishes') -> 27
# ('root vegetables', 'salt') -> 27
# ('other vegetables', 'house keeping products') -> 27
# ('pip fruit', 'semi-finished bread') -> 27
# ('tropical fruit', 'frozen dessert') -> 26
# ('salty snack', 'candy') -> 26
# ('napkins', 'hamburger meat') -> 26
# ('domestic eggs', 'candy') -> 26
# ('tropical fruit', 'turkey') -> 26
# ('yogurt', 'processed cheese') -> 26
# ('hygiene articles', 'oil') -> 26
# ('whipped/sour cream', 'ice cream') -> 26
# ('root vegetables', 'canned vegetables') -> 26
# ('shopping bags', 'red/blush wine') -> 26
# ('bottled water', 'packaged fruit/vegetables') -> 26
# ('sugar', 'hygiene articles') -> 26
# ('brown bread', 'ham') -> 26
# ('root vegetables', 'frozen fish') -> 26
# ('bottled beer', 'frozen meals') -> 26
# ('ham', 'sliced cheese') -> 26
# ('beef', 'dessert') -> 26
# ('whole milk', 'pet care') -> 26
# ('whole milk', 'vinegar') -> 26
# ('white bread', 'candy') -> 26
# ('margarine', 'berries') -> 26
# ('other vegetables', 'frozen potato products') -> 26
# ('citrus fruit', 'soft cheese') -> 26
# ('coffee', 'butter milk') -> 26
# ('bottled beer', 'canned beer') -> 26
# ('fruit/vegetable juice', 'specialty bar') -> 26
# ('soda', 'seasonal products') -> 26
# ('whole milk', 'white wine') -> 26
# ('rolls/buns', 'packaged fruit/vegetables') -> 26
# ('rolls/buns', 'white wine') -> 26
# ('curd', 'oil') -> 26
# ('margarine', 'ham') -> 26
# ('frozen vegetables', 'pickled vegetables') -> 26
# ('root vegetables', 'canned fish') -> 26
# ('beef', 'salty snack') -> 26
# ('pastry', 'meat') -> 26
# ('newspapers', 'semi-finished bread') -> 26
# ('whole milk', 'popcorn') -> 26
# ('bottled water', 'ice cream') -> 26
# ('berries', 'grapes') -> 26
# ('fruit/vegetable juice', 'specialty chocolate') -> 26
# ('tropical fruit', 'mustard') -> 26
# ('long life bakery product', 'candy') -> 26
# ('domestic eggs', 'cat food') -> 26
# ('long life bakery product', 'frozen meals') -> 26
# ('other vegetables', 'condensed milk') -> 25
# ('hamburger meat', 'hygiene articles') -> 25
# ('beef', 'grapes') -> 25
# ('frankfurter', 'oil') -> 25
# ('frozen vegetables', 'herbs') -> 25
# ('sausage', 'detergent') -> 25
# ('coffee', 'berries') -> 25
# ('coffee', 'onions') -> 25
# ('canned beer', 'waffles') -> 25
# ('canned beer', 'red/blush wine') -> 25
# ('pip fruit', 'baking powder') -> 25
# ('frankfurter', 'ham') -> 25
# ('tropical fruit', 'frozen fish') -> 25
# ('white bread', 'frozen meals') -> 25
# ('shopping bags', 'detergent') -> 25
# ('coffee', 'condensed milk') -> 25
# ('newspapers', 'hard cheese') -> 25
# ('bottled water', 'semi-finished bread') -> 25
# ('yogurt', 'packaged fruit/vegetables') -> 25
# ('frankfurter', 'mustard') -> 25
# ('white bread', 'salty snack') -> 25
# ('root vegetables', 'mayonnaise') -> 25
# ('coffee', 'sliced cheese') -> 25
# ...
# ('rolls/buns', 'tidbits') -> 12
# ('yogurt', 'candles') -> 12
# ('hygiene articles', 'pasta') -> 12
# ('salty snack', 'cat food') -> 12
# ('bottled beer', 'condensed milk') -> 12
# ('beef', 'dog food') -> 12
# ('tropical fruit', 'flower (seeds)') -> 12
# ('sausage', 'popcorn') -> 12
# ('bottled water', 'jam') -> 12
# ('butter', 'jam') -> 12
# ('beef', 'candy') -> 12
# ('butter', 'semi-finished bread') -> 12
# ('hard cheese', 'canned vegetables') -> 12
# ('shopping bags', 'frozen dessert') -> 12
# ('napkins', 'potted plants') -> 12
# ('chocolate', 'ice cream') -> 12
# ('canned beer', 'frozen meals') -> 12
# ('newspapers', 'sweet spreads') -> 12
# ('cream cheese', 'herbs') -> 12
# ('berries', 'frozen meals') -> 12
# ('frozen meals', 'cat food') -> 12
# ('curd', 'ice cream') -> 12
# ('shopping bags', 'rice') -> 12
# ('sausage', 'specialty cheese') -> 12
# ('frozen vegetables', 'flower (seeds)') -> 12
# ('meat', 'ice cream') -> 12
# ('domestic eggs', 'sweet spreads') -> 12
# ('beef', 'jam') -> 12
# ('yogurt', 'spices') -> 12
# ('onions', 'frozen meals') -> 12
# ('tropical fruit', 'white wine') -> 12
# ('hamburger meat', 'sauces') -> 12
# ('sausage', 'cling film/bags') -> 12
# ('butter', 'Instant food products') -> 12
# ('frozen vegetables', 'flour') -> 12
# ('bottled beer', 'specialty bar') -> 12
# ('soda', 'turkey') -> 12
# ('citrus fruit', 'white wine') -> 12
# ('cream cheese', 'meat spreads') -> 11
# ('newspapers', 'processed cheese') -> 11
# ('waffles', 'flour') -> 11
# ('rolls/buns', 'spices') -> 11
# ('whole milk', 'artif. sweetener') -> 11
# ('grapes', 'detergent') -> 11
# ('cream cheese', 'spread cheese') -> 11
# ('UHT-milk', 'hard cheese') -> 11
# ('pickled vegetables', 'processed cheese') -> 11
# ('tropical fruit', 'frozen potato products') -> 11
# ('chocolate', 'frozen potato products') -> 11
# ('butter', 'candles') -> 11
# ('specialty chocolate', 'oil') -> 11
# ('rolls/buns', 'brandy') -> 11
# ('waffles', 'red/blush wine') -> 11
# ('hamburger meat', 'detergent') -> 11
# ('detergent', 'pasta') -> 11
# ('yogurt', 'photo/film') -> 11
# ('shopping bags', 'softener') -> 11
# ('bottled beer', 'chewing gum') -> 11
# ('oil', 'dishes') -> 11
# ('citrus fruit', 'canned fruit') -> 11
# ('sugar', 'soft cheese') -> 11
# ('salty snack', 'cake bar') -> 11
# ('butter', 'frozen fish') -> 11
# ('curd', 'cereals') -> 11
# ('waffles', 'soft cheese') -> 11
# ('sliced cheese', 'frozen fish') -> 11
# ('specialty bar', 'cake bar') -> 11
# ('shopping bags', 'salt') -> 11
# ('pip fruit', 'spices') -> 11
# ('beef', 'dish cleaner') -> 11
# ('canned beer', 'ice cream') -> 11
# ('rolls/buns', 'tea') -> 11
# ('salty snack', 'sliced cheese') -> 11
# ('rolls/buns', 'cereals') -> 11
# ('dessert', 'canned vegetables') -> 11
# ('hygiene articles', 'canned fish') -> 11
# ('beef', 'turkey') -> 11
# ('hygiene articles', 'sliced cheese') -> 11
# ('domestic eggs', 'soups') -> 11
# ('domestic eggs', 'packaged fruit/vegetables') -> 11
# ('curd', 'mustard') -> 11
# ('misc. beverages', 'pickled vegetables') -> 11
# ('specialty chocolate', 'butter milk') -> 11
# ('pip fruit', 'pet care') -> 11
# ('fruit/vegetable juice', 'pet care') -> 11
# ('frankfurter', 'dish cleaner') -> 11
# ('specialty bar', 'cat food') -> 11
# ('napkins', 'pasta') -> 11
# ('soda', 'softener') -> 11
# ('oil', 'cat food') -> 11
# ('beef', 'frozen potato products') -> 11
# ('hygiene articles', 'ice cream') -> 11
# ('hygiene articles', 'house keeping products') -> 11
# ('frozen vegetables', 'roll products') -> 11
# ('whole milk', 'honey') -> 11
# ('rolls/buns', 'snack products') -> 11
# ('rolls/buns', 'photo/film') -> 11
# ('sausage', 'turkey') -> 11
# ('beef', 'misc. beverages') -> 11
# ('napkins', 'rice') -> 11
# ('fruit/vegetable juice', 'frozen dessert') -> 11
# ('coffee', 'mayonnaise') -> 11
# ('napkins', 'frozen potato products') -> 11
# ('oil', 'dish cleaner') -> 11
# ('cat food', 'dish cleaner') -> 11
# ('bottled water', 'frozen potato products') -> 11
# ('soda', 'snack products') -> 11
# ('frozen vegetables', 'chewing gum') -> 11
# ('frozen vegetables', 'liquor (appetizer)') -> 11
# ('domestic eggs', 'white wine') -> 11
# ('whole milk', 'soap') -> 11
# ('long life bakery product', 'red/blush wine') -> 11
# ('potted plants', 'herbs') -> 11
# ('newspapers', 'Instant food products') -> 11
# ('coffee', 'soups') -> 11
# ('pastry', 'roll products') -> 11
# ('candy', 'grapes') -> 11
# ('citrus fruit', 'Instant food products') -> 11
# ('shopping bags', 'female sanitary products') -> 11
# ('sugar', 'meat') -> 11
# ('margarine', 'dishes') -> 11
# ('pastry', 'vinegar') -> 11
# ('frankfurter', 'vinegar') -> 11
# ('brown bread', 'white wine') -> 11
# ('napkins', 'white wine') -> 11
# ('onions', 'cat food') -> 11
# ('whipped/sour cream', 'seasonal products') -> 11
# ('citrus fruit', 'cake bar') -> 11
# ('frozen vegetables', 'cake bar') -> 11
# ('candy', 'seasonal products') -> 11
# ('margarine', 'packaged fruit/vegetables') -> 11
# ('long life bakery product', 'house keeping products') -> 11
# ('brown bread', 'flower (seeds)') -> 11
# ('frozen vegetables', 'soups') -> 11
# ('frozen meals', 'beverages') -> 11
# ('sugar', 'dishes') -> 11
# ('newspapers', 'instant coffee') -> 11
# ('frozen vegetables', 'instant coffee') -> 11
# ('waffles', 'meat') -> 11
# ('shopping bags', 'Instant food products') -> 11
# ('brown bread', 'sweet spreads') -> 11
# ('chicken', 'salt') -> 11
# ('newspapers', 'cake bar') -> 11
# ('beef', 'white wine') -> 11
# ('white bread', 'chewing gum') -> 11
# ('canned beer', 'grapes') -> 11
# ('grapes', 'baking powder') -> 11
# ('pork', 'chewing gum') -> 11
# ('brown bread', 'mayonnaise') -> 11
# ('soda', 'photo/film') -> 11
# ('shopping bags', 'flower (seeds)') -> 11
# ('citrus fruit', 'vinegar') -> 11
# ('domestic eggs', 'cake bar') -> 11
# ('curd', 'house keeping products') -> 11
# ('detergent', 'potted plants') -> 11
# ('other vegetables', 'specialty fat') -> 11
# ('pip fruit', 'dog food') -> 11
# ('pip fruit', 'softener') -> 11
# ('chicken', 'hard cheese') -> 11
# ('long life bakery product', 'frozen fish') -> 11
# ('long life bakery product', 'cling film/bags') -> 11
# ('yogurt', 'artif. sweetener') -> 11
# ('sliced cheese', 'grapes') -> 11
# ('margarine', 'rice') -> 11
# ('soda', 'zwieback') -> 11
# ('yogurt', 'dental care') -> 11
# ('chicken', 'processed cheese') -> 11
# ('misc. beverages', 'cat food') -> 11
# ('dessert', 'flour') -> 11
# ('citrus fruit', 'mayonnaise') -> 11
# ('sugar', 'processed cheese') -> 11
# ('chicken', 'semi-finished bread') -> 11
# ('white bread', 'specialty chocolate') -> 11
# ('frankfurter', 'soups') -> 11
# ('hamburger meat', 'specialty chocolate') -> 11
# ('salty snack', 'meat') -> 11
# ('salty snack', 'semi-finished bread') -> 11
# ('pastry', 'flower (seeds)') -> 11
# ('bottled beer', 'flower (seeds)') -> 11
# ('brown bread', 'dish cleaner') -> 11
# ('onions', 'canned vegetables') -> 11
# ('onions', 'specialty cheese') -> 11
# ('white bread', 'frozen potato products') -> 11
# ('other vegetables', 'syrup') -> 11
# ('soda', 'rice') -> 11
# ('yogurt', 'ketchup') -> 11
# ('specialty chocolate', 'chewing gum') -> 11
# ('hamburger meat', 'pickled vegetables') -> 11
# ('cream cheese', 'mayonnaise') -> 11
# ('sugar', 'pasta') -> 11
# ('tropical fruit', 'popcorn') -> 11
# ('soda', 'cleaner') -> 11
# ('pork', 'soft cheese') -> 11
# ('onions', 'ice cream') -> 11
# ('rolls/buns', 'specialty cheese') -> 11
# ('hard cheese', 'cat food') -> 11
# ('newspapers', 'canned vegetables') -> 11
# ('detergent', 'softener') -> 11
# ('meat', 'detergent') -> 11
# ('hamburger meat', 'sweet spreads') -> 11
# ('dessert', 'detergent') -> 11
# ('shopping bags', 'roll products') -> 11
# ('margarine', 'ice cream') -> 11
# ('butter milk', 'ice cream') -> 11
# ('candy', 'semi-finished bread') -> 11
# ('cat food', 'semi-finished bread') -> 11
# ('cream cheese', 'sweet spreads') -> 11
# ('chocolate', 'spread cheese') -> 11
# ('hygiene articles', 'grapes') -> 11
# ('butter', 'white wine') -> 11
# ('rolls/buns', 'liquor') -> 11
# ('tropical fruit', 'jam') -> 11
# ('onions', 'pickled vegetables') -> 11
# ('other vegetables', 'canned fruit') -> 11
# ('pork', 'canned fish') -> 11
# ('root vegetables', 'liquor') -> 11
# ('dessert', 'hard cheese') -> 11
# ('sugar', 'chewing gum') -> 11
# ('pastry', 'frozen fish') -> 11
# ('napkins', 'cake bar') -> 11
# ('berries', 'semi-finished bread') -> 11
# ('dessert', 'processed cheese') -> 11
# ('pip fruit', 'mustard') -> 11
# ('pastry', 'sweet spreads') -> 11
# ('frozen vegetables', 'frozen potato products') -> 11
# ('soda', 'liver loaf') -> 11
# ('soda', 'dental care') -> 11
# ('bottled beer', 'tea') -> 11
# ('hamburger meat', 'soft cheese') -> 11
# ('pickled vegetables', 'canned fish') -> 11
# ('other vegetables', 'photo/film') -> 11
# ('tropical fruit', 'spices') -> 11
# ('UHT-milk', 'ham') -> 11
# ('butter', 'specialty cheese') -> 11
# ('beef', 'red/blush wine') -> 11
# ('rolls/buns', 'popcorn') -> 11
# ('chocolate', 'canned vegetables') -> 11
# ('yogurt', 'abrasive cleaner') -> 10
# ('other vegetables', 'bathroom cleaner') -> 10
# ('other vegetables', 'artif. sweetener') -> 10
# ('soda', 'cereals') -> 10
# ('tropical fruit', 'cereals') -> 10
# ('pastry', 'cereals') -> 10
# ('domestic eggs', 'cereals') -> 10
# ('brown bread', 'baking powder') -> 10
# ('salty snack', 'seasonal products') -> 10
# ('whole milk', 'sparkling wine') -> 10
# ('frozen vegetables', 'condensed milk') -> 10
# ('oil', 'salt') -> 10
# ('whipped/sour cream', 'rice') -> 10
# ('chocolate', 'rice') -> 10
# ('hamburger meat', 'rice') -> 10
# ('soda', 'bathroom cleaner') -> 10
# ('sausage', 'softener') -> 10
# ('frozen vegetables', 'red/blush wine') -> 10
# ('dessert', 'semi-finished bread') -> 10
# ('dessert', 'packaged fruit/vegetables') -> 10
# ('sausage', 'rice') -> 10
# ('sugar', 'misc. beverages') -> 10
# ('hard cheese', 'rice') -> 10
# ('sausage', 'candles') -> 10
# ('dessert', 'dishes') -> 10
# ('beef', 'cling film/bags') -> 10
# ('waffles', 'cake bar') -> 10
# ('whipped/sour cream', 'cereals') -> 10
# ('cream cheese', 'frozen fish') -> 10
# ('waffles', 'frozen fish') -> 10
# ('frozen meals', 'soft cheese') -> 10
# ('beef', 'spread cheese') -> 10
# ('sugar', 'condensed milk') -> 10
# ('sausage', 'flower (seeds)') -> 10
# ('yogurt', 'skin care') -> 10
# ('curd', 'canned vegetables') -> 10
# ('napkins', 'frozen dessert') -> 10
# ('dessert', 'canned fish') -> 10
# ('sugar', 'canned fish') -> 10
# ('sugar', 'soups') -> 10
# ('curd', 'packaged fruit/vegetables') -> 10
# ('pickled vegetables', 'mustard') -> 10
# ('napkins', 'vinegar') -> 10
# ('hamburger meat', 'flour') -> 10
# ('chocolate', 'chewing gum') -> 10
# ('sausage', 'abrasive cleaner') -> 10
# ('berries', 'misc. beverages') -> 10
# ('specialty chocolate', 'detergent') -> 10
# ('misc. beverages', 'ham') -> 10
# ('curd', 'dish cleaner') -> 10
# ('root vegetables', 'curd cheese') -> 10
# ('frozen meals', 'butter milk') -> 10
# ('sausage', 'liver loaf') -> 10
# ('coffee', 'sweet spreads') -> 10
# ('long life bakery product', 'sweet spreads') -> 10
# ('salty snack', 'baking powder') -> 10
# ('frozen vegetables', 'specialty cheese') -> 10
# ('bottled water', 'canned vegetables') -> 10
# ('frozen vegetables', 'liver loaf') -> 10
# ('hygiene articles', 'semi-finished bread') -> 10
# ('canned fish', 'mustard') -> 10
# ('white bread', 'frozen dessert') -> 10
# ('yogurt', 'male cosmetics') -> 10
# ('napkins', 'packaged fruit/vegetables') -> 10
# ('chocolate', 'frozen fish') -> 10
# ('berries', 'mustard') -> 10
# ('coffee', 'chocolate marshmallow') -> 10
# ('hamburger meat', 'roll products') -> 10
# ('butter', 'packaged fruit/vegetables') -> 10
# ('meat', 'flour') -> 10
# ('newspapers', 'soups') -> 10
# ('hamburger meat', 'canned fish') -> 10
# ('bottled water', 'Instant food products') -> 10
# ('canned beer', 'white bread') -> 10
# ('chicken', 'dish cleaner') -> 10
# ('newspapers', 'chocolate marshmallow') -> 10
# ('coffee', 'candles') -> 10
# ('sliced cheese', 'cat food') -> 10
# ('cat food', 'dishes') -> 10
# ('frankfurter', 'roll products') -> 10
# ('pastry', 'instant coffee') -> 10
# ('UHT-milk', 'grapes') -> 10
# ('frankfurter', 'flower (seeds)') -> 10
# ('napkins', 'seasonal products') -> 10
# ('cream cheese', 'seasonal products') -> 10
# ('yogurt', 'liquor (appetizer)') -> 10
# ('margarine', 'cake bar') -> 10
# ('domestic eggs', 'flower (seeds)') -> 10
# ('bottled water', 'female sanitary products') -> 10
# ('whipped/sour cream', 'mustard') -> 10
# ('beef', 'candles') -> 10
# ('margarine', 'beverages') -> 10
# ('frozen meals', 'misc. beverages') -> 10
# ('pip fruit', 'Instant food products') -> 10
# ('pork', 'Instant food products') -> 10
# ('brown bread', 'dog food') -> 10
# ('berries', 'baking powder') -> 10
# ('white bread', 'grapes') -> 10
# ('cream cheese', 'flour') -> 10
# ('pork', 'canned vegetables') -> 10
# ('chocolate', 'dental care') -> 10
# ('newspapers', 'potted plants') -> 10
# ('fruit/vegetable juice', 'finished products') -> 10
# ('salty snack', 'frozen fish') -> 10
# ('root vegetables', 'zwieback') -> 10
# ('yogurt', 'soups') -> 10
# ('pastry', 'soups') -> 10
# ('long life bakery product', 'mayonnaise') -> 10
# ('cream cheese', 'vinegar') -> 10
# ('detergent', 'house keeping products') -> 10
# ('domestic eggs', 'dog food') -> 10
# ('napkins', 'dog food') -> 10
# ('frozen vegetables', 'dog food') -> 10
# ('root vegetables', 'sparkling wine') -> 10
# ('rolls/buns', 'nuts/prunes') -> 10
# ('sliced cheese', 'mustard') -> 10
# ('sugar', 'grapes') -> 10
# ('UHT-milk', 'sliced cheese') -> 10
# ('sausage', 'chocolate marshmallow') -> 10
# ('long life bakery product', 'chocolate marshmallow') -> 10
# ('sliced cheese', 'pickled vegetables') -> 10
# ('soda', 'sauces') -> 10
# ('bottled water', 'mayonnaise') -> 10
# ('frozen vegetables', 'mayonnaise') -> 10
# ('napkins', 'kitchen towels') -> 10
# ('white bread', 'condensed milk') -> 10
# ('sausage', 'finished products') -> 10
# ('whipped/sour cream', 'cake bar') -> 10
# ('butter', 'cake bar') -> 10
# ('butter', 'soups') -> 10
# ('bottled water', 'soups') -> 10
# ('domestic eggs', 'Instant food products') -> 10
# ('frankfurter', 'Instant food products') -> 10
# ('bottled water', 'popcorn') -> 10
# ('napkins', 'pet care') -> 10
# ('beef', 'canned vegetables') -> 10
# ('ham', 'spread cheese') -> 10
# ('canned beer', 'flour') -> 10
# ('flour', 'roll products') -> 10
# ('soda', 'tidbits') -> 10
# ('candy', 'frozen fish') -> 10
# ('brown bread', 'roll products') -> 10
# ('newspapers', 'dog food') -> 10
# ('pip fruit', 'dishes') -> 10
# ('pastry', 'house keeping products') -> 10
# ('coffee', 'jam') -> 10
# ('onions', 'turkey') -> 10
# ('candy', 'butter milk') -> 10
# ('chocolate', 'dishes') -> 10
# ('UHT-milk', 'pasta') -> 10
# ('onions', 'semi-finished bread') -> 10
# ('pip fruit', 'kitchen towels') -> 10
# ('brown bread', 'dishes') -> 10
# ('frozen vegetables', 'house keeping products') -> 10
# ('salty snack', 'red/blush wine') -> 10
# ('long life bakery product', 'frozen dessert') -> 10
# ('hygiene articles', 'specialty bar') -> 10
# ('beef', 'sweet spreads') -> 10
# ('chocolate', 'sweet spreads') -> 10
# ('misc. beverages', 'chewing gum') -> 10
# ('newspapers', 'herbs') -> 10
# ('frozen vegetables', 'sweet spreads') -> 10
# ('specialty chocolate', 'beverages') -> 10
# ('frozen meals', 'semi-finished bread') -> 10
# ('bottled beer', 'popcorn') -> 10
# ('hamburger meat', 'mayonnaise') -> 10
# ('citrus fruit', 'sweet spreads') -> 10
# ('cream cheese', 'ice cream') -> 10
# ('bottled water', 'instant coffee') -> 10
# ('frozen meals', 'canned fish') -> 10
# ('frozen vegetables', 'specialty bar') -> 10
# ('hamburger meat', 'specialty bar') -> 10
# ('hygiene articles', 'candy') -> 10
# ('cream cheese', 'cling film/bags') -> 10
# ('berries', 'cling film/bags') -> 10
# ('onions', 'mayonnaise') -> 10
# ('pastry', 'potato products') -> 10
# ('soda', 'nut snack') -> 10
# ('salty snack', 'condensed milk') -> 10
# ('frankfurter', 'cake bar') -> 10
# ('frankfurter', 'salt') -> 10
# ('hygiene articles', 'cling film/bags') -> 10
# ('hamburger meat', 'misc. beverages') -> 10
# ('onions', 'frozen fish') -> 10
# ('brown bread', 'house keeping products') -> 10
# ('coffee', 'salt') -> 10
# ('citrus fruit', 'chocolate marshmallow') -> 10
# ('cream cheese', 'salt') -> 10
# ('brown bread', 'frozen fish') -> 10
# ('pork', 'misc. beverages') -> 10
# ('hygiene articles', 'processed cheese') -> 10
# ('chicken', 'flower (seeds)') -> 10
# ('tropical fruit', 'dental care') -> 10
# ('salty snack', 'kitchen towels') -> 10
# ('specialty chocolate', 'pickled vegetables') -> 10
# ('citrus fruit', 'spices') -> 10
# ('newspapers', 'pet care') -> 10
# ('bottled water', 'liquor') -> 10
# ('butter milk', 'pickled vegetables') -> 10
# ('UHT-milk', 'cake bar') -> 10
# ('pip fruit', 'house keeping products') -> 10
